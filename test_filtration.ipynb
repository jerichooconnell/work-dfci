# %%
# %matplotlib nbagg
# %load_ext autoreload
# %autoreload 2

# %%
import detector_class as dc
import spekpy as sp
import matplotlib.pyplot as plt
# Define the layers for the detector
materials = ['Al','Ti','Water','Cesium Iodide','Sn','Si','Perovskite','Si']
densities = [None,None,1,None,None,None,None,None]
thicknesses = [1,1,1,0.6,0.1,0.1,0.6,0.1]
colors = ['gray','darkgray','blue','red','whitesmoke','white','red','white']

spectra = sp.Spek(kvp=140,th=14)

# Create the detector
detector = dc.Detector()
detector.add_layers(materials,thicknesses,densities=densities)
plt.figure(figsize=[5,10])
ax = plt.gca()
detector.plot_detector(ax,colors)
plt.show()
# Out:
# <img src="data:image/png;base64,..." width="500">

# %%
plt.figure()
ax = plt.gca()
detector.plot_attenuation(ax)
plt.show()
s.mu_data.mu_over_rho_coefficients()
# Out:
# <img src="data:image/png;base64,..." width="640">
# Al
# Ti
# Water
# Cs
# ---------------------------------------------------------------------------
# Warning                                   Traceback (most recent call last)
# Cell In[3], line 3
#       1 plt.figure()
#       2 ax = plt.gca()
# ----> 3 detector.plot_attenuation(ax)
#       4 plt.show()
#
# File ~/1-work/detector_class.py:282, in Detector.plot_attenuation(self, axis)
#     277 '''
#     278 This function plots the attenuation coefficient for the detector.
#     279 axis: matplotlib axis object
#     280 '''
#     281 for layer in self.layers:
# --> 282     layer.plot_attenuation(axis)
#     283 axis.set_xlabel('Energy [keV]')
#     284 axis.set_ylabel('Attenuation Coefficient [cm^2/g]')
#
# File ~/1-work/detector_class.py:64, in Detector.layer.plot_attenuation(self, axis)
#      62 print(self.layer['material'])
#      63 if self.layer['density'] == 1:
# ...

# %%
s = sp.Spek(kvp=140,th=14)

# %%
detector.filter_spectrum_through_detector(s)

# %%
plt.figure()
ax = plt.gca()
detector.plot_absorbed_spectra(ax)
plt.show()
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
s.state.model_parameters.kvp
# Out:
# 140

# %%
sp.SpekTools.make_composition_def('Perovskite',4.2,[(6,0.01937),(1,0.9755),(7,.02259),(82,0.3342),(53,0.6141)],'CH3NH3PbI3','Lead Iodide Pervoskite')

# %%
ses.mu_data.get_mu_t('Perovskite',s.model.k, 1)
# Out:
# array([1.90426159e+03, 9.02891210e+02, 5.03249011e+02, 5.52868281e+02,
#        4.02174260e+02, 2.94071597e+02, 2.22922072e+02, 2.89007621e+02,
#        3.04597274e+02, 2.42890360e+02, 1.96863879e+02, 1.61949962e+02,
#        1.34980590e+02, 1.13780190e+02, 9.68768542e+01, 8.32165875e+01,
#        7.20549508e+01, 6.28364212e+01, 5.51546104e+01, 4.86969944e+01,
#        4.32207040e+01, 3.85432708e+01, 3.45366490e+01, 3.10592365e+01,
#        4.06518749e+01, 3.68928810e+01, 3.35488833e+01, 3.05910868e+01,
#        3.34603427e+01, 3.08540259e+01, 3.11617212e+01, 2.88388189e+01,
#        2.67442645e+01, 2.48481416e+01, 2.31270317e+01, 2.15670567e+01,
#        2.01494099e+01, 1.88578919e+01, 1.76745976e+01, 1.65882095e+01,
#        1.55921871e+01, 1.46771420e+01, 1.38329898e+01, 1.30528678e+01,
#        1.23323286e+01, 1.16656815e+01, 1.10478836e+01, 1.04744549e+01,
#        9.93986724e+00, 9.44083272e+00, 8.97575949e+00, 8.54175317e+00,
# ...

# %%
plt.figure()
ax = plt.gca()
detector.plot_attenuation(ax)
plt.show()
# Out:
# <img src="data:image/png;base64,..." width="972">
# Al
# Ti
# Water
# Cesium Iodide
# Sn
# Si
# Perovskite
# Si

# %%
sp.Spek.load_from_file('/home/jericho/Downloads/W_spectrum_25.txt',spectrum_delimeter=' ')

# %%
xx, yy = s.get_spectrum()

plt.figure()
plt.plot(xx,yy)
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
s = sp.Spek.load_from_file('25Xbeam.txt',spectrum_delimeter=)

# %%
s.export_spectrum('test_csv',delim=' ')
# Out:
# spectrum name
# /home/jericho/1-work/test_csv

# %%
filename = '/home/jericho/Downloads/C_spectrum_25.txt'
import csv
import numpy as np
with open(filename, 'r') as csvfile:
    # Read the file
    reader = csv.reader(csvfile, delimiter=' ')
    # Convert the file to a list
    x = list(reader)
    # Convert the list to a numpy array
    x = np.array(x)
    # Convert the numpy array from string to float
    x = x.astype(np.float64)

# %%
xx, yy = s.get_spectrum()

plt.figure()
plt.plot(x[:80,0],x[:80,1])
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
np.savetxt('25Xbeam_C.txt',x[:80,:2],delimiter=' ')

# %%
x[:,0]*=1000

# %%
x[:,1]*=10e12
