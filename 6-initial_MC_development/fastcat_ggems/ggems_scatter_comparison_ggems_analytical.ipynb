# %%
# %pylab qt
# %load_ext autoreload
# %autoreload 2
# Out:
# %pylab is deprecated, use %matplotlib inline and import the required libraries.
# Populating the interactive namespace from numpy and matplotlib

# %%
# Loop through the ggems mhd files and save them to an array
import glob
import fastcat as fc
import numpy as np
import matplotlib.pyplot as plt
import mpl_interactions as pli
from mpl_interactions import ipyplot as iplt
# Zoom the ggems projections
from scipy.ndimage import zoom

ggems_scatter_files = glob.glob(
    '/home/jericho/1-Workspace/opengate_ggems_comparison/2-fastcat_scatter_XCAT/test/out/ggems_3e09_121kVp_*scatter.mhd'
)
ggems_primary_files = glob.glob(
    '/home/jericho/1-Workspace/opengate_ggems_comparison/2-fastcat_scatter_XCAT/test/out/ggems_3e09_121kVp_*[!scatter].mhd'
)

ggems_scatter_files.sort()
ggems_primary_files.sort()

ggems_primary_projections = []
ggems_scatter_projections = []

for ggems_scatter_file, ggems_primary_file in zip(ggems_scatter_files, ggems_primary_files):
    ggems_prmiary, b, c = fc.utils.read_mhd(ggems_primary_file)
    ggems_scatter, b, c = fc.utils.read_mhd(ggems_scatter_file)

    ggems_primary_projections.append(ggems_prmiary.squeeze())
    ggems_scatter_projections.append(ggems_scatter.squeeze())

flood_file = '/home/jericho/1-Workspace/opengate_ggems_comparison/fastcat_scatter_bowtie/test/out/ggems_1e09_121kVp_0000_flood_field.mhd'
ggems_flood, b, c = fc.utils.read_mhd(flood_file)

# Load the pickled phantom
pkl_file = '/home/jericho/1-Workspace/opengate_ggems_comparison/2-fastcat_scatter_XCAT/test/ggems_1e03_121kVp.pkl'
phantom = np.load(pkl_file, allow_pickle=True)

# Convert the phantom angles to degrees
phantom_angles = phantom.angles * 180 / np.pi

# Define the denoising functions
def downsize_block(image, block_size):
    image_size = image.shape[0]
    block_size = int(block_size)
    downsize = image_size//block_size
    image = image[:downsize*block_size, :downsize*block_size]
    image = image.reshape(downsize, block_size, downsize,
                          block_size).mean(axis=(1, 3))
    return image

def denoise_projections(projections):
    projections_zoomed = []

    for projection in projections:
        projection_zoomed_downsized = downsize_block(projection, 64)
        projection_zoomed = zoom(
            projection_zoomed_downsized, 64, order=4, mode='nearest')
        # Adjust the mean of the zoomed image to match the original
        projection_zoomed = projection_zoomed * \
            np.mean(projection) / np.mean(projection_zoomed)
        projections_zoomed.append(projection_zoomed)
    
    return projections_zoomed

# zoom the scatter projections using the zoom fromfunction
ggems_scatter_denoised = denoise_projections(ggems_scatter_projections)

# %%
plt.close('all')

# %%
# Get the simulation parameters
simulation_parameters = phantom.simulation_parameters
detector_material = simulation_parameters['detector_material']
spectrum = simulation_parameters['spectrum']

# Load the spectrum as a fastcat spectrum object
s = fc.Spectrum()
s.load(spectrum_file=spectrum)

det = fc.Detector(s,'CsI-784-micrometer')
# angles = phantom.angles
angles = np.linspace(0, 2*np.pi, 2, endpoint=False)

# return the projections
phantom.simulate(det,s,angles,mgy=0,
                    ASG=False, scat_on=False,
                    det_on=False,
                    filter_on=False,
                    return_intensity=True)# Get primary fastcat projections
# Out:
# [2024-04-11 12:50:49,568] {ggems_simulate.py:626} INFO - Running Simulations
# [2024-04-11 12:50:49,569] {ggems_simulate.py:654} INFO -     Simulating 10 keV
# [2024-04-11 12:50:49,764] {ggems_simulate.py:654} INFO -     Simulating 20 keV
# [2024-04-11 12:50:49,956] {ggems_simulate.py:654} INFO -     Simulating 30 keV
# [2024-04-11 12:50:50,154] {ggems_simulate.py:654} INFO -     Simulating 40 keV
# [2024-04-11 12:50:50,350] {ggems_simulate.py:654} INFO -     Simulating 50 keV
# [2024-04-11 12:50:50,550] {ggems_simulate.py:654} INFO -     Simulating 60 keV
# [2024-04-11 12:50:50,738] {ggems_simulate.py:654} INFO -     Simulating 70 keV
# [2024-04-11 12:50:50,921] {ggems_simulate.py:654} INFO -     Simulating 80 keV
# [2024-04-11 12:50:51,102] {ggems_simulate.py:654} INFO -     Simulating 90 keV
# [2024-04-11 12:50:51,280] {ggems_simulate.py:654} INFO -     Simulating 100 keV
# [2024-04-11 12:50:51,466] {ggems_simulate.py:892} INFO - Weighting simulations
# [2024-04-11 12:50:51,468] {ggems_simulate.py:922} INFO - Simulation Finished
# [2024-04-11 12:50:51,469] {ggems_simulate.py:923} INFO -     Analytical projections are stored as: phantom.primary_projections
# [2024-04-11 12:50:51,469] {ggems_simulate.py:925} INFO -     Analytical flood field are stored as: phantom.flood_field

# %%
plt.figure()
plt.subplot(131)
plt.imshow(phantom.primary_projections[0].squeeze(), cmap='turbo')
plt.subplot(132)
plt.imshow(ggems_primary_projections[0].squeeze(), cmap='turbo')
plt.subplot(133)
# define standard scalar function
def ss(x,crop=20):
    return (x - np.mean(x[crop:-crop,crop:-crop])) / np.std(x[crop:-crop,crop:-crop])
diffs = np.abs(ss(phantom.primary_projections[0].squeeze()) - ss(ggems_primary_projections[0].squeeze()))/ss(phantom.primary_projections[0].squeeze())
plt.imshow(diffs, cmap='bwr',vmin=-0.1,vmax=0.1)

# %%
plt.figure()
xx, yy = np.arange(phantom.primary_projections[0].shape[0]), np.arange(phantom.primary_projections[0].shape[1])
# pli.heatmap_slicer(xx,yy,[ss(ggems_primary_projections[0].squeeze()), ss(phantom.primary_projections[0].squeeze())])

A = -np.log(ggems_primary_projections[0].squeeze()/ggems_flood)
B = -np.log(phantom.primary_projections[0].squeeze()/phantom.flood_field)

A[A<0] = 0
B[B<0] = 0
pli.heatmap_slicer(xx,yy,[ggems_primary_projections[0].squeeze(),ggems_flood.squeeze()])
# Out:
# /tmp/ipykernel_76451/755422000.py:5: RuntimeWarning: divide by zero encountered in divide
#   A = -np.log(ggems_primary_projections[0].squeeze()/ggems_flood)
# (<Figure size 1800x900 with 3 Axes>,
#  array([<Axes: title={'center': 'heatmap_0'}, xlabel='X', ylabel='Y'>,
#         <Axes: title={'center': 'heatmap_1'}, xlabel='X'>,
#         <Axes: title={'center': 'Horizontal'}>], dtype=object))

# %%
# plt.figure()
# pli.hyperslicer(phantom.intensity, axis=0, cmap='gray')

ggems_primary_only = np.array(ggems_primary_projections) - np.array(ggems_scatter_projections)
# Set the mean and standard deviation of the ggems primary only projections to match the fastcat projections
def normalize_mean_and_std(array1,array2):
    array1 = array1 - np.mean(array1)
    array1 = array1 * np.std(array2) / np.std(array1)
    array1 = array1 + np.mean(array2)
    return array1

phantom_projections = normalize_mean_and_std(phantom.primary_projections, ggems_primary_only)

# %%
# Set up a shallow neural network to map the fastcat projections to the ggems_primary_only projections using sklearn
from sklearn.neural_network import MLPRegressor
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
from sklearn.metrics import mean_squared_error

# Split the data into training and testing sets
X_train, X_test, y_train, y_test = train_test_split(
    phantom.primary_projections[0].flatten()[::4], ggems_primary_only[0].flatten()[::4], test_size=0.2, random_state=42)

# Scale the data
scaler = StandardScaler()
scaler.fit(X_train.reshape(-1, 1))
X_train_scaled = scaler.transform(X_train.reshape(-1, 1))
X_test_scaled = scaler.transform(X_test.reshape(-1, 1))

# # Define the neural network
mlp = MLPRegressor(hidden_layer_sizes=(10,10,10),
                   activation='relu',
                   solver='adam',
                   max_iter=100,
                   verbose=True,
                   random_state=42)

# Use an svm instead of a neural network
# from sklearn.svm import SVR
# mlp = SVR(kernel='rbf', C=100, gamma=0.1, epsilon=.1)

# Train the neural network
mlp.fit(X_train_scaled, y_train)

# Predict the test data
predictions = mlp.predict(X_test_scaled)

# Plot the predictions vs the actual data
plt.figure()
plt.scatter(y_test, predictions)
plt.xlabel('True Values')
plt.ylabel('Predictions')

# Plot the residuals
plt.figure()
plt.scatter(y_test, y_test - predictions)
plt.xlabel('True Values')
plt.ylabel('Residuals')

# Calculate the mean squared error
print('Mean squared error: ', mean_squared_error(y_test, predictions))
# Out:
# Iteration 1, loss = 5079627.42367155
# Iteration 2, loss = 4712694.09200674
# Iteration 3, loss = 2854775.72186742
# Iteration 4, loss = 462779.33236809
# Iteration 5, loss = 4588.05823628
# Iteration 6, loss = 3116.60730374
# Iteration 7, loss = 2962.75229921
# Iteration 8, loss = 2818.54798114
# Iteration 9, loss = 2688.72887496
# Iteration 10, loss = 2587.56384054
# Iteration 11, loss = 2509.13761810
# Iteration 12, loss = 2460.06899254
# Iteration 13, loss = 2426.65209088
# Iteration 14, loss = 2393.60478554
# Iteration 15, loss = 2359.77790522
# Iteration 16, loss = 2328.88708329
# Iteration 17, loss = 2296.49388598
# Iteration 18, loss = 2266.55671971
# Iteration 19, loss = 2237.71950853
# Iteration 20, loss = 2207.02505965
# Iteration 21, loss = 2180.06188751
# Iteration 22, loss = 2152.38452074
# Iteration 23, loss = 2130.55890815
# Iteration 24, loss = 2113.77011090
# Iteration 25, loss = 2098.35472276
# Iteration 26, loss = 2085.85926745
# Iteration 27, loss = 2079.47522403
# Iteration 28, loss = 2070.01135667
# Iteration 29, loss = 2062.43762743
# Iteration 30, loss = 2053.39209624
# Iteration 31, loss = 2050.21930290
# Iteration 32, loss = 2044.25826935
# Iteration 33, loss = 2041.56662490
# Iteration 34, loss = 2037.00222065
# Iteration 35, loss = 2031.14446193
# Iteration 36, loss = 2030.31442787
# Iteration 37, loss = 2026.90163554
# Iteration 38, loss = 2020.45376758
# Iteration 39, loss = 2022.68017338
# Iteration 40, loss = 2015.25043954
# Iteration 41, loss = 2010.42086554
# Iteration 42, loss = 2009.06626808
# Iteration 43, loss = 2006.19260311
# Iteration 44, loss = 2001.52423746
# Iteration 45, loss = 2001.71039810
# Iteration 46, loss = 1994.06043965
# Iteration 47, loss = 1994.43979457
# Iteration 48, loss = 1996.14216146
# Iteration 49, loss = 1981.30023501
# Iteration 50, loss = 1978.62990647
# Iteration 51, loss = 1979.91946225
# Iteration 52, loss = 1971.78968307
# Iteration 53, loss = 1969.29242754
# Iteration 54, loss = 1967.49841330
# Iteration 55, loss = 1959.23137347
# Iteration 56, loss = 1958.87883828
# Iteration 57, loss = 1952.98738460
# Iteration 58, loss = 1948.36844715
# Iteration 59, loss = 1950.32500284
# Iteration 60, loss = 1940.71639531
# Iteration 61, loss = 1940.33925532
# Iteration 62, loss = 1936.76860002
# Iteration 63, loss = 1935.81632320
# Iteration 64, loss = 1928.93546286
# Iteration 65, loss = 1930.45651793
# Iteration 66, loss = 1924.18916054
# Iteration 67, loss = 1919.31021926
# Iteration 68, loss = 1916.05219291
# Iteration 69, loss = 1913.02163807
# Iteration 70, loss = 1911.49839525
# Iteration 71, loss = 1905.53788700
# Iteration 72, loss = 1905.77324007
# Iteration 73, loss = 1899.74569534
# Iteration 74, loss = 1897.98070455
# Iteration 75, loss = 1900.75921099
# Iteration 76, loss = 1891.59635900
# Iteration 77, loss = 1891.26780829
# Iteration 78, loss = 1888.68880716
# Iteration 79, loss = 1886.58228677
# Iteration 80, loss = 1885.86122187
# Iteration 81, loss = 1878.75948430
# Iteration 82, loss = 1882.43079676
# Iteration 83, loss = 1878.21277391
# Iteration 84, loss = 1873.85117289
# Iteration 85, loss = 1872.58121924
# Iteration 86, loss = 1870.01504858
# Iteration 87, loss = 1867.54318483
# Iteration 88, loss = 1867.62137014
# Iteration 89, loss = 1862.05051958
# Iteration 90, loss = 1858.35425207
# Iteration 91, loss = 1859.54195975
# Iteration 92, loss = 1855.90909935
# Iteration 93, loss = 1854.08099697
# Iteration 94, loss = 1850.00646140
# Iteration 95, loss = 1849.80377635
# Iteration 96, loss = 1846.55865329
# Iteration 97, loss = 1843.61424507
# Iteration 98, loss = 1839.10612764
# Iteration 99, loss = 1838.22727064
# Iteration 100, loss = 1836.17474003
# Mean squared error:  3612.374713982706
# /home/jericho/anaconda3/envs/tigre_fastcat/lib/python3.10/site-packages/sklearn/neural_network/_multilayer_perceptron.py:691: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (100) reached and the optimization hasn't converged yet.
#   warnings.warn(
# libGL error: MESA-LOADER: failed to open radeonsi: /usr/lib/dri/radeonsi_dri.so: cannot open shared object file: No such file or directory (search paths /usr/lib/x86_64-linux-gnu/dri:\$${ORIGIN}/dri:/usr/lib/dri, suffix _dri)
# libGL error: failed to load driver: radeonsi
# libGL error: MESA-LOADER: failed to open radeonsi: /usr/lib/dri/radeonsi_dri.so: cannot open shared object file: No such file or directory (search paths /usr/lib/x86_64-linux-gnu/dri:\$${ORIGIN}/dri:/usr/lib/dri, suffix _dri)
# libGL error: failed to load driver: radeonsi
# libGL error: MESA-LOADER: failed to open swrast: /usr/lib/dri/swrast_dri.so: cannot open shared object file: No such file or directory (search paths /usr/lib/x86_64-linux-gnu/dri:\$${ORIGIN}/dri:/usr/lib/dri, suffix _dri)
# libGL error: failed to load driver: swrast

# %%
# Use the neural network to predict the ggems primary only projections from the fastcat projections
ggems_primary_only_nn = []
for projection in phantom.primary_projections:
    projection_scaled = scaler.transform(projection.flatten().reshape(-1, 1))
    projection_nn = mlp.predict(projection_scaled)
    projection_nn = projection_nn.reshape(projection.shape)
    ggems_primary_only_nn.append(projection_nn)

# scale the ggems neural network projections to match the fastcat projections
ggems_fastcat_nn = normalize_mean_and_std(np.array(phantom.primary_projections), np.array(ggems_primary_only))

# %%
perc_diff_primary = (np.array(ggems_primary_only)-np.array(ggems_fastcat_nn[-1::-1]))/np.max(ggems_primary_only)*100

plt.figure()
ctrl = pli.hyperslicer(np.array(perc_diff_primary), cmap='bwr',
                        vmax=5,vmin=-5)

# %%
phantom_projections = phantom.primary_projections

# Downsize the perc_diff using the downsize_block function
perc_diff = (np.array(ggems_scatter_denoised)-np.array(ggems_scatter_projections))/np.max(ggems_scatter_projections)*100
perc_diff_small = []
for i in range(len(perc_diff)):
    perc_diff_small.append(downsize_block(perc_diff[i], 16))

# Plot the ggems projections
fig, (axes) = plt.subplots(ncols=2, nrows=3, figsize=(5.8,10))

# Plot the denoised ggems projections
controls = pli.hyperslicer(np.array(ggems_scatter_denoised),
                           ax=axes[1][0], cmap='jet',vmax=np.percentile(np.array(ggems_scatter_denoised),99),
                           vmin=np.percentile(np.array(ggems_scatter_denoised),1),play_buttons=True)
axes[1][0].set_title('Denoised GGEMS scatter')

ggems_primary_only = np.array(ggems_primary_projections) - np.array(ggems_scatter_projections)

# Plot the ggems projections
c2 = pli.hyperslicer(np.array(ggems_primary_only), ax=axes[0][1], cmap='gray',controls=controls,
                     vmax=np.percentile(np.array(ggems_primary_only),99),
                     vmin=np.percentile(np.array(ggems_primary_only),1))
axes[0][1].set_title('GGEMS Primary')

# Plot the phantom phantom_projections
c1 = pli.hyperslicer(np.array(phantom_projections)[-1::-1], ax=axes[1][1], cmap='gray',controls=controls,
                     vmax=np.percentile(np.array(phantom_projections),99),
                     vmin=np.percentile(np.array(phantom_projections),1))
axes[1][1].set_title('Analytical Primary')

# Plot the difference between the ggems and phantom projections
perc_diff_primary = (np.array(ggems_primary_only)-np.array(phantom_projections[-1::-1]))/np.max(phantom_projections)*100

c4 = pli.hyperslicer(np.array(perc_diff_primary), ax=axes[2][1], cmap='bwr',controls=controls,
                        vmax=5,vmin=-5)
axes[2][1].set_title('Perc. Diff. [%]')

# Add a colorbar
plt.colorbar(ax=axes[2][1])

# Plot the ggems projections
c2 = pli.hyperslicer(np.array(ggems_scatter_projections), ax=axes[0][0], cmap='jet',controls=controls,
                     vmax=np.percentile(np.array(ggems_scatter_projections),99),
                     vmin=np.percentile(np.array(ggems_scatter_projections),1))

axes[0][0].set_title('GGEMS Scatter')

# Plot the ggems primary projections
c3 = pli.hyperslicer(np.array(perc_diff_small),ax=axes[2][0], cmap='bwr',vmax=5,vmin=-5,controls=controls)
plt.colorbar(ax=axes[2][0])
axes[2][0].set_title('Perc. Diff. [%]')
plt.tight_layout()

# Turn off the axes
for ax in axes.flatten():
    ax.axis('off')
# Define a function that given an angle and radius returns x and y coordinates
# def f(axis0,radius=220,offset=0,x0=256,y0=256,na=90):
#     angle = np.deg2rad(axis0*360/na)
#     x = radius * np.cos(angle+offset) + x0
#     y = radius * np.sin(angle+offset) + y0
#     return np.array([[x,y],[x,y],[x,y]])

# iplt.plot(f, ax=axes[4], a=(0.1,10), b=(0.1,10), parametric=True,ylim=[0,1],xlim=[1,na],play_buttons=True)
# plt.imshow(phantom.phantom[50, :, :], cmap='gray')
# iplt.scatter(f, ax=axes[3][0], controls=controls,play_buttons=True,c='r',marker='>',parametric=True,)

# Add a label in the image saying source position
# axes[3].text(50, 50, 'Source Position', color='r', fontsize=12)

# %%
# Save the figure as a gif using mpl_interactions
# save as a gif
anim = controls.save_animation("phantoms_ggems_analytical+denoised.gif", fig, "axis0", interval=120)
# Out:
# [2023-12-07 16:51:50,649] {animation.py:1060} INFO - Animation.save using <class 'matplotlib.animation.FFMpegWriter'>
# [2023-12-07 16:51:50,649] {animation.py:322} DEBUG - frame size in pixels is 580 x 964
# [2023-12-07 16:51:50,650] {animation.py:338} INFO - MovieWriter._run: running command: ffmpeg -f rawvideo -vcodec rawvideo -s 580x964 -pix_fmt rgba -framerate 8.333333333333334 -i pipe: -filter_complex 'split [a][b];[a] palettegen [p];[b][p] paletteuse' -y phantoms_ggems_analytical+denoised.gif
# [2023-12-07 16:51:50,655] {animation.py:366} DEBUG - MovieWriter.grab_frame: Grabbing frame.
# [2023-12-07 16:51:50,748] {animation.py:366} DEBUG - MovieWriter.grab_frame: Grabbing frame.
# [2023-12-07 16:51:50,836] {animation.py:366} DEBUG - MovieWriter.grab_frame: Grabbing frame.
# [2023-12-07 16:51:50,927] {animation.py:366} DEBUG - MovieWriter.grab_frame: Grabbing frame.
# [2023-12-07 16:51:51,015] {animation.py:366} DEBUG - MovieWriter.grab_frame: Grabbing frame.
# [2023-12-07 16:51:51,105] {animation.py:366} DEBUG - MovieWriter.grab_frame: Grabbing frame.
# [2023-12-07 16:51:51,193] {animation.py:366} DEBUG - MovieWriter.grab_frame: Grabbing frame.
# [2023-12-07 16:51:51,282] {animation.py:366} DEBUG - MovieWriter.grab_frame: Grabbing frame.
# [2023-12-07 16:51:51,373] {animation.py:366} DEBUG - MovieWriter.grab_frame: Grabbing frame.
# [2023-12-07 16:51:51,462] {animation.py:366} DEBUG - MovieWriter.grab_frame: Grabbing frame.
# [2023-12-07 16:51:51,553] {animation.py:366} DEBUG - MovieWriter.grab_frame: Grabbing frame.
# [2023-12-07 16:51:51,643] {animation.py:366} DEBUG - MovieWriter.grab_frame: Grabbing frame.
# [2023-12-07 16:51:51,732] {animation.py:366} DEBUG - MovieWriter.grab_frame: Grabbing frame.
# [2023-12-07 16:51:51,821] {animation.py:366} DEBUG - MovieWriter.grab_frame: Grabbing frame.
# [2023-12-07 16:51:51,914] {animation.py:366} DEBUG - MovieWriter.grab_frame: Grabbing frame.
# [2023-12-07 16:51:52,007] {animation.py:366} DEBUG - MovieWriter.grab_frame: Grabbing frame.
# [2023-12-07 16:51:52,096] {animation.py:366} DEBUG - MovieWriter.grab_frame: Grabbing frame.
# [2023-12-07 16:51:52,187] {animation.py:366} DEBUG - MovieWriter.grab_frame: Grabbing frame.
# [2023-12-07 16:51:52,277] {animation.py:366} DEBUG - MovieWriter.grab_frame: Grabbing frame.
# [2023-12-07 16:51:52,366] {animation.py:366} DEBUG - MovieWriter.grab_frame: Grabbing frame.
# [2023-12-07 16:51:52,457] {animation.py:366} DEBUG - MovieWriter.grab_frame: Grabbing frame.
# [2023-12-07 16:51:52,546] {animation.py:366} DEBUG - MovieWriter.grab_frame: Grabbing frame.
# [2023-12-07 16:51:52,637] {animation.py:366} DEBUG - MovieWriter.grab_frame: Grabbing frame.
# [2023-12-07 16:51:52,728] {animation.py:366} DEBUG - MovieWriter.grab_frame: Grabbing frame.
# [2023-12-07 16:51:52,816] {animation.py:366} DEBUG - MovieWriter.grab_frame: Grabbing frame.
# [2023-12-07 16:51:52,905] {animation.py:366} DEBUG - MovieWriter.grab_frame: Grabbing frame.
# [2023-12-07 16:51:52,994] {animation.py:366} DEBUG - MovieWriter.grab_frame: Grabbing frame.
# [2023-12-07 16:51:53,090] {animation.py:366} DEBUG - MovieWriter.grab_frame: Grabbing frame.
# [2023-12-07 16:51:53,190] {animation.py:366} DEBUG - MovieWriter.grab_frame: Grabbing frame.
# [2023-12-07 16:51:53,282] {animation.py:366} DEBUG - MovieWriter.grab_frame: Grabbing frame.
# [2023-12-07 16:51:53,370] {animation.py:366} DEBUG - MovieWriter.grab_frame: Grabbing frame.
# [2023-12-07 16:51:53,459] {animation.py:366} DEBUG - MovieWriter.grab_frame: Grabbing frame.
# [2023-12-07 16:51:53,546] {animation.py:366} DEBUG - MovieWriter.grab_frame: Grabbing frame.
# [2023-12-07 16:51:53,633] {animation.py:366} DEBUG - MovieWriter.grab_frame: Grabbing frame.
# [2023-12-07 16:51:53,723] {animation.py:366} DEBUG - MovieWriter.grab_frame: Grabbing frame.
# [2023-12-07 16:51:53,813] {animation.py:366} DEBUG - MovieWriter.grab_frame: Grabbing frame.
# [2023-12-07 16:51:53,902] {animation.py:366} DEBUG - MovieWriter.grab_frame: Grabbing frame.
# [2023-12-07 16:51:53,991] {animation.py:366} DEBUG - MovieWriter.grab_frame: Grabbing frame.
# [2023-12-07 16:51:54,080] {animation.py:366} DEBUG - MovieWriter.grab_frame: Grabbing frame.
# [2023-12-07 16:51:54,165] {animation.py:366} DEBUG - MovieWriter.grab_frame: Grabbing frame.
# [2023-12-07 16:51:54,251] {animation.py:366} DEBUG - MovieWriter.grab_frame: Grabbing frame.
# [2023-12-07 16:51:54,339] {animation.py:366} DEBUG - MovieWriter.grab_frame: Grabbing frame.
# [2023-12-07 16:51:54,429] {animation.py:366} DEBUG - MovieWriter.grab_frame: Grabbing frame.
# [2023-12-07 16:51:54,514] {animation.py:366} DEBUG - MovieWriter.grab_frame: Grabbing frame.
# [2023-12-07 16:51:54,603] {animation.py:366} DEBUG - MovieWriter.grab_frame: Grabbing frame.
# [2023-12-07 16:51:54,692] {animation.py:366} DEBUG - MovieWriter.grab_frame: Grabbing frame.
# [2023-12-07 16:51:54,778] {animation.py:366} DEBUG - MovieWriter.grab_frame: Grabbing frame.
# [2023-12-07 16:51:54,865] {animation.py:366} DEBUG - MovieWriter.grab_frame: Grabbing frame.
# [2023-12-07 16:51:54,951] {animation.py:366} DEBUG - MovieWriter.grab_frame: Grabbing frame.
# [2023-12-07 16:51:55,038] {animation.py:366} DEBUG - MovieWriter.grab_frame: Grabbing frame.
# [2023-12-07 16:51:55,125] {animation.py:366} DEBUG - MovieWriter.grab_frame: Grabbing frame.
# [2023-12-07 16:51:55,211] {animation.py:366} DEBUG - MovieWriter.grab_frame: Grabbing frame.
# [2023-12-07 16:51:55,298] {animation.py:366} DEBUG - MovieWriter.grab_frame: Grabbing frame.
# [2023-12-07 16:51:55,384] {animation.py:366} DEBUG - MovieWriter.grab_frame: Grabbing frame.
# [2023-12-07 16:51:55,469] {animation.py:366} DEBUG - MovieWriter.grab_frame: Grabbing frame.
# [2023-12-07 16:51:55,557] {animation.py:366} DEBUG - MovieWriter.grab_frame: Grabbing frame.
# [2023-12-07 16:51:55,643] {animation.py:366} DEBUG - MovieWriter.grab_frame: Grabbing frame.
# [2023-12-07 16:51:55,731] {animation.py:366} DEBUG - MovieWriter.grab_frame: Grabbing frame.
# [2023-12-07 16:51:55,829] {animation.py:366} DEBUG - MovieWriter.grab_frame: Grabbing frame.
# [2023-12-07 16:51:55,919] {animation.py:366} DEBUG - MovieWriter.grab_frame: Grabbing frame.
# [2023-12-07 16:51:56,011] {animation.py:366} DEBUG - MovieWriter.grab_frame: Grabbing frame.
# [2023-12-07 16:51:56,107] {animation.py:366} DEBUG - MovieWriter.grab_frame: Grabbing frame.
# [2023-12-07 16:51:56,196] {animation.py:366} DEBUG - MovieWriter.grab_frame: Grabbing frame.
# [2023-12-07 16:51:56,282] {animation.py:366} DEBUG - MovieWriter.grab_frame: Grabbing frame.
# [2023-12-07 16:51:56,376] {animation.py:366} DEBUG - MovieWriter.grab_frame: Grabbing frame.
# [2023-12-07 16:51:56,462] {animation.py:366} DEBUG - MovieWriter.grab_frame: Grabbing frame.
# [2023-12-07 16:51:56,548] {animation.py:366} DEBUG - MovieWriter.grab_frame: Grabbing frame.
# [2023-12-07 16:51:56,635] {animation.py:366} DEBUG - MovieWriter.grab_frame: Grabbing frame.
# [2023-12-07 16:51:56,724] {animation.py:366} DEBUG - MovieWriter.grab_frame: Grabbing frame.
# [2023-12-07 16:51:56,810] {animation.py:366} DEBUG - MovieWriter.grab_frame: Grabbing frame.
# [2023-12-07 16:51:56,897] {animation.py:366} DEBUG - MovieWriter.grab_frame: Grabbing frame.
# [2023-12-07 16:51:56,985] {animation.py:366} DEBUG - MovieWriter.grab_frame: Grabbing frame.
# [2023-12-07 16:51:57,074] {animation.py:366} DEBUG - MovieWriter.grab_frame: Grabbing frame.
# [2023-12-07 16:51:57,161] {animation.py:366} DEBUG - MovieWriter.grab_frame: Grabbing frame.
# [2023-12-07 16:51:57,248] {animation.py:366} DEBUG - MovieWriter.grab_frame: Grabbing frame.
# [2023-12-07 16:51:57,334] {animation.py:366} DEBUG - MovieWriter.grab_frame: Grabbing frame.
# [2023-12-07 16:51:57,426] {animation.py:366} DEBUG - MovieWriter.grab_frame: Grabbing frame.
# [2023-12-07 16:51:57,512] {animation.py:366} DEBUG - MovieWriter.grab_frame: Grabbing frame.
# [2023-12-07 16:51:57,599] {animation.py:366} DEBUG - MovieWriter.grab_frame: Grabbing frame.
# [2023-12-07 16:51:57,686] {animation.py:366} DEBUG - MovieWriter.grab_frame: Grabbing frame.
# [2023-12-07 16:51:57,774] {animation.py:366} DEBUG - MovieWriter.grab_frame: Grabbing frame.
# [2023-12-07 16:51:57,861] {animation.py:366} DEBUG - MovieWriter.grab_frame: Grabbing frame.
# [2023-12-07 16:51:57,947] {animation.py:366} DEBUG - MovieWriter.grab_frame: Grabbing frame.
# [2023-12-07 16:51:58,035] {animation.py:366} DEBUG - MovieWriter.grab_frame: Grabbing frame.
# [2023-12-07 16:51:58,125] {animation.py:366} DEBUG - MovieWriter.grab_frame: Grabbing frame.
# [2023-12-07 16:51:58,212] {animation.py:366} DEBUG - MovieWriter.grab_frame: Grabbing frame.
# [2023-12-07 16:51:58,298] {animation.py:366} DEBUG - MovieWriter.grab_frame: Grabbing frame.
# [2023-12-07 16:51:58,385] {animation.py:366} DEBUG - MovieWriter.grab_frame: Grabbing frame.
# [2023-12-07 16:51:58,473] {animation.py:366} DEBUG - MovieWriter.grab_frame: Grabbing frame.
# [2023-12-07 16:51:59,760] {animation.py:356} DEBUG - MovieWriter stderr:
# ffmpeg version 4.2.2 Copyright (c) 2000-2019 the FFmpeg developers
#   built with gcc 7.3.0 (crosstool-NG 1.23.0.449-a04d0)
#   configuration: --prefix=/tmp/build/80754af9/ffmpeg_1587154242452/_h_env_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placeho --cc=/tmp/build/80754af9/ffmpeg_1587154242452/_build_env/bin/x86_64-conda_cos6-linux-gnu-cc --disable-doc --enable-avresample --enable-gmp --enable-hardcoded-tables --enable-libfreetype --enable-libvpx --enable-pthreads --enable-libopus --enable-postproc --enable-pic --enable-pthreads --enable-shared --enable-static --enable-version3 --enable-zlib --enable-libmp3lame --disable-nonfree --enable-gpl --enable-gnutls --disable-openssl --enable-libopenh264 --enable-libx264
#   libavutil      56. 31.100 / 56. 31.100
#   libavcodec     58. 54.100 / 58. 54.100
#   libavformat    58. 29.100 / 58. 29.100
#   libavdevice    58.  8.100 / 58.  8.100
#   libavfilter     7. 57.100 /  7. 57.100
#   libavresample   4.  0.  0 /  4.  0.  0
#   libswscale      5.  5.100 /  5.  5.100
#   libswresample   3.  5.100 /  3.  5.100
#   libpostproc    55.  5.100 / 55.  5.100
# Input #0, rawvideo, from 'pipe:':
#   Duration: N/A, start: 0.000000, bitrate: 149098 kb/s
#     Stream #0:0: Video: rawvideo (RGBA / 0x41424752), rgba, 580x964, 149098 kb/s, 8.33 tbr, 8.33 tbn, 8.33 tbc
# Stream mapping:
#   Stream #0:0 (rawvideo) -> split
#   paletteuse -> Stream #0:0 (gif)
# Output #0, gif, to 'phantoms_ggems_analytical+denoised.gif':
#   Metadata:
#     encoder         : Lavf58.29.100
#     Stream #0:0: Video: gif, pal8, 580x964, q=2-31, 200 kb/s, 8.33 fps, 100 tbn, 8.33 tbc
#     Metadata:
#       encoder         : Lavc58.54.100 gif
# frame=    0 fps=0.0 q=0.0 size=       0kB time=00:00:00.00 bitrate=N/A speed=   0x
# frame=    0 fps=0.0 q=0.0 size=       0kB time=00:00:00.00 bitrate=N/A speed=   0x
# frame=    0 fps=0.0 q=0.0 size=       0kB time=00:00:00.00 bitrate=N/A speed=   0x
# frame=    0 fps=0.0 q=0.0 size=       0kB time=00:00:00.00 bitrate=N/A speed=   0x
# frame=    0 fps=0.0 q=0.0 size=       0kB time=00:00:00.00 bitrate=N/A speed=   0x
# frame=    0 fps=0.0 q=0.0 size=       0kB time=00:00:00.00 bitrate=N/A speed=   0x
# frame=    0 fps=0.0 q=0.0 size=       0kB time=00:00:00.00 bitrate=N/A speed=   0x
# frame=    0 fps=0.0 q=0.0 size=       0kB time=00:00:00.00 bitrate=N/A speed=   0x
# frame=    0 fps=0.0 q=0.0 size=       0kB time=00:00:00.00 bitrate=N/A speed=   0x
# frame=    0 fps=0.0 q=0.0 size=       0kB time=00:00:00.00 bitrate=N/A speed=   0x
# frame=    0 fps=0.0 q=0.0 size=       0kB time=00:00:00.00 bitrate=N/A speed=   0x
# frame=    0 fps=0.0 q=0.0 size=       0kB time=00:00:00.00 bitrate=N/A speed=   0x
# frame=    0 fps=0.0 q=0.0 size=       0kB time=00:00:00.00 bitrate=N/A speed=   0x
# frame=    0 fps=0.0 q=0.0 size=       0kB time=00:00:00.00 bitrate=N/A speed=   0x
# [Parsed_palettegen_1 @ 0x55f859610d80] 255(+1) colors generated out of 1056 colors; ratio=0.241477
# frame=   13 fps=1.6 q=-0.0 size=    1536kB time=00:00:01.45 bitrate=8677.9kbits/s speed=0.182x
# frame=   51 fps=6.0 q=-0.0 size=    6656kB time=00:00:06.01 bitrate=9072.5kbits/s speed=0.71x
# frame=   89 fps=9.9 q=-0.0 size=   11776kB time=00:00:10.57 bitrate=9126.7kbits/s speed=1.18x
# frame=   89 fps=9.9 q=-0.0 Lsize=   12099kB time=00:00:10.57 bitrate=9376.8kbits/s speed=1.18x
# video:12099kB audio:0kB subtitle:0kB other streams:0kB global headers:0kB muxing overhead: 0.000161%

# %%
# Plot the error between the ggems and phantom projections as a function of angle in terms of rmse 
rmse = []
rmse_scatter = []
for i in range(len(phantom_projections)):
    rmse_scatter.append(np.sqrt(np.mean(np.array(perc_diff_small[i])**2)))
    rmse.append(np.sqrt(np.mean(np.array(perc_diff_primary[i])**2)))

plt.figure()
plt.plot(angles,rmse_scatter,label='Scatter')
plt.plot(angles,rmse,label='Primary')
plt.xlabel('Angle [degrees]')
plt.ylabel('RMSE [%]')
plt.legend()
plt.title('RMSE vs Angle')
# Out:
# Text(0.5, 1.0, 'RMSE vs Angle')

# %%
mean_projection = np.mean(np.array(ggems_projections), axis=0)
mean_projection_zoom = zoom(downsize_block(
    mean_projection, 64), 64, order=5, mode='nearest')

pli.heatmap_slicer(np.arange(0, mean_projection.shape[0]),
                   np.arange(0, mean_projection.shape[1]),
                   (mean_projection, mean_projection_zoom),
                   cmap='jet',
                   slices='both')
# Out:
# (<Figure size 1800x900 with 4 Axes>,
#  array([<Axes: title={'center': 'heatmap_0'}, xlabel='X', ylabel='Y'>,
#         <Axes: title={'center': 'heatmap_1'}, xlabel='X'>,
#         <Axes: title={'center': 'Horizontal'}>,
#         <Axes: title={'center': 'Vertical'}>], dtype=object))

# %%
# Do the same thing but for RectBivariateSpline
from scipy.interpolate import RectBivariateSpline
import numpy as np

ggems_projections_downsized_spline = []
for ggems_projection in ggems_projections_downsized:
    # Initialize the spline
    spline = RectBivariateSpline(np.arange(ggems_projection.shape[0]), np.arange(
        ggems_projection.shape[1]), ggems_projection, kx=4, ky=4, s=2)
    # Evaluate the spline on a finer grid
    x_fine, y_fine = np.meshgrid(np.linspace(0, ggems_projection.shape[0], ggems_projection.shape[0]*4), np.linspace(
        0, ggems_projection.shape[1], ggems_projection.shape[1]*4))
    z_fine = spline.ev(x_fine, y_fine)

    ggems_projections_downsized_spline.append(z_fine)

# Plot the ggems projections
plt.figure()
controls = pli.hyperslicer(
    np.array(ggems_projections_downsized_spline), cmap='jet')

# %%
# Out:
# Init signature:
# RectBivariateSpline(
#     x,
#     y,
#     z,
#     bbox=[None, None, None, None],
#     kx=3,
#     ky=3,
#     s=0,
# )
# Docstring:
# Bivariate spline approximation over a rectangular mesh.
#
# Can be used for both smoothing and interpolating data.
#
# Parameters
# ----------
# x,y : array_like
#     1-D arrays of coordinates in strictly ascending order.
#     Evaluated points outside the data range will be extrapolated.
# z : array_like
#     2-D array of data with shape (x.size,y.size).
# bbox : array_like, optional
#     Sequence of length 4 specifying the boundary of the rectangular
#     approximation domain, which means the start and end spline knots of
#     each dimension are set by these values. By default,
#     ``bbox=[min(x), max(x), min(y), max(y)]``.
# kx, ky : ints, optional
#     Degrees of the bivariate spline. Default is 3.
# s : float, optional
#     Positive smoothing factor defined for estimation condition:
#     ``sum((z[i]-f(x[i], y[i]))**2, axis=0) <= s`` where f is a spline
#     function. Default is ``s=0``, which is for interpolation.
#
# See Also
# --------
# BivariateSpline :
#     a base class for bivariate splines.
# UnivariateSpline :
#     a smooth univariate spline to fit a given set of data points.
# SmoothBivariateSpline :
#     a smoothing bivariate spline through the given points
# LSQBivariateSpline :
#     a bivariate spline using weighted least-squares fitting
# RectSphereBivariateSpline :
#     a bivariate spline over a rectangular mesh on a sphere
# SmoothSphereBivariateSpline :
#     a smoothing bivariate spline in spherical coordinates
# LSQSphereBivariateSpline :
#     a bivariate spline in spherical coordinates using weighted
#     least-squares fitting
# bisplrep :
#     a function to find a bivariate B-spline representation of a surface
# bisplev :
#     a function to evaluate a bivariate B-spline and its derivatives
#
# Notes
# -----
#
# If the input data is such that input dimensions have incommensurate
# units and differ by many orders of magnitude, the interpolant may have
# numerical artifacts. Consider rescaling the data before interpolating.
# File:           ~/anaconda3/envs/tigre_fastcat/lib/python3.11/site-packages/scipy/interpolate/_fitpack2.py
# Type:           type
# Subclasses:

# %%
phantom = np.load(
    '/home/jericho/Software/fastcat/fastcat/data/phantoms/ct_scan_head_mandible_large.npy')

# %%
plt.figure()
contr = pli.hyperslicer(phantom)

# %%
# load a binary file to an array
import numpy as np

phantom = np.load()

# %%
plt.figure()
pli.hyperslicer(phantom.phantom)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# File ~/anaconda3/envs/tigre_fastcat/lib/python3.11/site-packages/IPython/core/formatters.py:922, in IPythonDisplayFormatter.__call__(self, obj)
#     920 method = get_real_method(obj, self.print_method)
#     921 if method is not None:
# --> 922     method()
#     923     return True
#
# File ~/anaconda3/envs/tigre_fastcat/lib/python3.11/site-packages/mpl_interactions/controller.py:349, in Controls._ipython_display_(self)
#     348 def _ipython_display_(self):
# --> 349     ipy_display(self.vbox)
#
# AttributeError: 'Controls' object has no attribute 'vbox'
