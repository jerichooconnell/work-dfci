# %%
# %pylab nbagg
# Out:
# %pylab is deprecated, use %matplotlib inline and import the required libraries.
# Populating the interactive namespace from numpy and matplotlib

# %%
import mpl_interactions as pli

# %%
from read_in_data import load_itk

# %%
ggems_image, origin, space = load_itk('out/ggems_edep.mhd') # What is this in? - Should be MeV as well according to didier
ogate_image, origin, space = load_itk('out/gate_edep.mhd') # This is in MeV, MeV per particle? - I don't believe so

# %%
fig = plt.figure()
plt.subplot(121)
controls = pli.hyperslicer(np.log(ggems_image+1),cmap='jet',title='GGEMS z= {axis0:.2f} [0.1 mm]')
plt.axis('off')
# plt.title('GGEMs')
plt.subplot(122)
pli.hyperslicer(np.log(ogate_image+1),controls=controls,cmap='jet',title='Gate z= {axis0:.2f} [0.1 mm]')
plt.axis('off')
# Out:
# <img src="data:image/png;base64,..." width="640">
# ...
# (-0.5, 199.5, 199.5, -0.5)

# %%
# save as a gif
anim = controls.save_animation("freq-plot-1.gif", fig, "axis0", interval=150)

# %%
ind = 0
crop = 75
a = c = crop
b = d = -crop
plt.figure()
plt.subplot(121)
plt.imshow(np.log(ggems_image[ind]/100+1)[a:b,c:d],cmap='jet')
plt.axis('off')
plt.title('GGEMs')
plt.subplot(122)
plt.imshow(np.log(np.sum(ogate_image,ind)b[a:b,c:d]+1),cmap='jet')
plt.axis('off')
plt.title('Gate')
# Out:
# <img src="data:image/png;base64,..." width="640">
# Text(0.5, 1.0, 'Gate')

# %%
plt.figure()
pli.hyperslicer(ogate_image)
# Out:
# <img src="data:image/png;base64,..." width="640">
# ...

# %%
ggems_image.shape
# Out:
# (40, 200, 200)
