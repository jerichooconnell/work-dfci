# %%
# %pylab nbagg
# Out:
# %pylab is deprecated, use %matplotlib inline and import the required libraries.
# Populating the interactive namespace from numpy and matplotlib

# %% [markdown]
# ## Define a function to make the plots

# %%
def gen_plot(s,lab):
    xx, yy = s.get_spectrum()
    plt.plot(xx, yy/1000000,label=lab)
    plt.xlabel('Energy [keV]')
    plt.ylabel('Fluence $[cm^{-1} keV^{-2}]$')
    plt.title('Effect of Filtration on the Beam')

def gen_plot_norm(s,lab,s1,s2,s2_val,s2_title,info=False):
    xx, yy = s.get_spectrum()
    s1.plot(xx, yy/np.sum(yy),label=lab)
    s1.set_xlabel('Energy [keV]')
    s1.set_ylabel('Fluence $[cm^{-1} keV^{-2}]$')
    s1.set_title('Effect of Filtration on the Beam')
    if info:
        print(f'{lab} \n \t Mean Energy: {s.get_emean()} keV \n \t Fluence {s.get_flu()} photons cm-2')
    s2.semilogy(s.get_emean(),s2_val,'*')
    s2.set_title(f'{s2_title}')

# Could you write a class that stores an array as well as the mean of the array

def test_commom_prefix():

# %% [markdown]
# ## Define filtrations

# %%
materials = ['Al','Ti','Water','Cesium Iodide','Sn','Si','Cesium Iodide','Si']
thicknesses = [1,1,100,0.6,1,0.1,0.8,0.1]

# %%
s.get_flu()
# Out:
# 1451216.8096618727

# %%
s = sp.Spek(140,th=14)
plt.figure(figsize=[10,6])
s1 = plt.subplot(121)
s2 = plt.subplot(122)
for mat, thick in zip(materials, thicknesses):
    
    s.filter(mat, thick)
    gen_plot_norm(s,f'After {mat}',s1,s2,s.get_flu(),'Fluence',info='True')
    
s1.legend()
# Out:
# <img src="data:image/png;base64,..." width="1000">
# After Al
#  	 Mean Energy: 54.593342176399304 keV
#  	 Fluence 621357133.2898784 photons cm-2
# After Ti
#  	 Mean Energy: 67.30153669944103 keV
#  	 Fluence 320299481.525131 photons cm-2
# After Water
#  	 Mean Energy: 74.12755672036242 keV
#  	 Fluence 41569848.23324217 photons cm-2
# After Cesium Iodide
#  	 Mean Energy: 92.14785007797303 keV
#  	 Fluence 12010158.626091514 photons cm-2
# After Sn
#  	 Mean Energy: 107.0762864848611 keV
#  	 Fluence 2793631.881487618 photons cm-2
# After Si
#  	 Mean Energy: 107.08454206876762 keV
#  	 Fluence 2781923.2036577007 photons cm-2
# After Cesium Iodide
#  	 Mean Energy: 111.1650608843523 keV
#  	 Fluence 1457122.223987454 photons cm-2
# After Si
#  	 Mean Energy: 111.17078855198137 keV
#  	 Fluence 1451216.8096618727 photons cm-2

# %%
mat, thick
# Out:
# ('Si', 0.1)
