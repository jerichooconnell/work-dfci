# %%
# %pylab inline
# %load_ext autoreload
# %autoreload 2
# Out:
# %pylab is deprecated, use %matplotlib inline and import the required libraries.
# Populating the interactive namespace from numpy and matplotlib

# %%
# Read the mhd file from data
from gecco.utils import write_run_all_script, write_python_script_head
import os

import mpl_interactions as pli
from gecco import patient_data
import gecco as fc
import numpy as np
from gecco.utils import nrrd_to_mhd, cropping_tool

# %% [markdown]
# # General Instructions
#
# ## 1) Save dicom to Nrrd file
#
# Open slicer => load dicom data => export as nrrd
#
# (Look into slicer documentation for help with this)
# Nrrd is the default export type
#
# ## 2) Dataset generation instructions
#
# ### 2.1) Open Notebook 1-Write_pytho_sim_script.ipynb
#
# Change fmx_path to point at your FastMC executable file.
#
# Change the path to point to the nrrd files you want to load
# One line for each file in the nrrd_files dictionary object
#
# ## 2.2) Change the orientation
#
# We need to find the dimensional transposition that maps the axes such that the first dimension is axial
# Otherwise the CBCT will not rotate around the right dimension
#
# To do this: Run the cells up to the "Plot one slice: Make sure it is axial" cell. If this shows an axial plot
# keep the orientation in the second variable in the nrrd_files dictionary (e.g. `[1,0,2]`) otherwise change the mapping
# to a different one (e.g. `[2,1,0]`), repeat running the cells between the dictionary initialization and the plotting
# until it is axial.
#
# ## 2.3) Crop the arrays
#
# After finding the orientation for all files run the cropping cell for each nrrd file,
#
# **! Only after finding the orientation, if you have the wrong orientation the crop will be wrong.**
#
# Use the GUI to crop the file. Make sure your image isocenter is at the center of the image.
# There isn't another way to shift the field of view of the image! So make sure it is aligned
# If there is too much air on one side of the image, the isocenter will be shifted and the patient
# might be outside the field of view of the CBCT.
#
# => This tells GECCO to save the phantom with a crop
# => Important for centering the projections
#
# Repeat this process for all files
#
# ## 2.4) Run a test run
#
# Complete all cells including the files under "Write all the files this is into a test directory"
#
# This writes runs with only 1e6 primaries to a directory for testing.
#
# When this is completed open a terminal and run the command `./run_all.sh` in the test_python_scripts directory
#
# There should be green GGEMS simulations showing up in the output and Done - Completed without errors with
# GECCO finding and loading the projections, something like:
#
# ```
# [2024-06-04 09:56:47,260] {patient_data.py:258} INFO - ggems files loaded
# [2024-06-04 09:56:47,260] {patient_data.py:259} INFO -     Scatter files:
# [2024-06-04 09:56:47,260] {patient_data.py:262} INFO -         /home/jericho/Software/gecco/gecco/data/user_phantoms/Pelvis_Prostate_Patient_2/fastmc_output_7/fastmc_0.00-scatter.mhd
# [2024-06-04 09:56:47,260] {patient_data.py:264} INFO -           Shape:(360, 360)
# [2024-06-04 09:56:47,260] {patient_data.py:262} INFO -         /home/jericho/Software/gecco/gecco/data/user_phantoms/Pelvis_Prostate_Patient_2/fastmc_output_7/fastmc_108.00-scatter.mhd
# [2024-06-04 09:56:47,261] {patient_data.py:264} INFO -           Shape:(360, 360)
# [2024-06-04 09:56:47,261] {patient_data.py:262} INFO -         /home/jericho/Software/gecco/gecco/data/user_phantoms/Pelvis_Prostate_Patient_2/fastmc_output_7/fastmc_144.00-scatter.mhd
# [2024-06-04 09:56:47,261] {patient_data.py:264} INFO -           Shape:(360, 360)
# [2024-06-04 09:56:47,261] {patient_data.py:262} INFO -         /home/jericho/Software/gecco/gecco/data/user_phantoms/Pelvis_Prostate_Patient_2/fastmc_output_7/fastmc_180.00-scatter.mhd
# [2024-06-04 09:56:47,261] {patient_data.py:264} INFO -           Shape:(360, 360)
# [2024-06-04 09:56:47,261] {patient_data.py:262} INFO -         /home/jericho/Software/gecco/gecco/data/user_phantoms/Pelvis_Prostate_Patient_2/fastmc_output_7/fastmc_216.00-scatter.mhd
# [2024-06-04 09:56:47,261] {patient_data.py:264} INFO -           Shape:(360, 360)
# [2024-06-04 09:56:47,261] {patient_data.py:262} INFO -         /home/jericho/Software/gecco/gecco/data/user_phantoms/Pelvis_Prostate_Patient_2/fastmc_output_7/fastmc_252.00-scatter.mhd
# [2024-06-04 09:56:47,261] {patient_data.py:264} INFO -           Shape:(360, 360)
# [2024-06-04 09:56:47,261] {patient_data.py:262} INFO -         /home/jericho/Software/gecco/gecco/data/user_phantoms/Pelvis_Prostate_Patient_2/fastmc_output_7/fastmc_288.00-scatter.mhd
# [2024-06-04 09:56:47,261] {patient_data.py:264} INFO -           Shape:(360, 360)
# [2024-06-04 09:56:47,261] {patient_data.py:262} INFO -         /home/jericho/Software/gecco/gecco/data/user_phantoms/Pelvis_Prostate_Patient_2/fastmc_output_7/fastmc_324.00-scatter.mhd
# [2024-06-04 09:56:47,261] {patient_data.py:264} INFO -           Shape:(360, 360)
# [2024-06-04 09:56:47,261] {patient_data.py:262} INFO -         /home/jericho/Software/gecco/gecco/data/user_phantoms/Pelvis_Prostate_Patient_2/fastmc_output_7/fastmc_36.00-scatter.mhd
# [2024-06-04 09:56:47,261] {patient_data.py:264} INFO -           Shape:(360, 360)
# [2024-06-04 09:56:47,261] {patient_data.py:262} INFO -         /home/jericho/Software/gecco/gecco/data/user_phantoms/Pelvis_Prostate_Patient_2/fastmc_output_7/fastmc_72.00-scatter.mhd
# [2024-06-04 09:56:47,261] {patient_data.py:264} INFO -           Shape:(360, 360)
#
# Done - Completed without errors
# ```
#
# If this is not the case GECCO is not finding the simulation files, look in the output of the function for clues
# as to why this might be.
#
# ## 2.5) Run the full simulation
#
# If the test completes and find the files then complete the rest of the notebook
#
# Then go into the python_scripts directory and run `./run_all.sh` to start the 1e10 primary photon simulations.

# %% [markdown]
# Read the nrrd_file

# %%
# Number : [path, orientation, crop]
# fmc_path = '/home/jericho/Downloads/FastMC_Jan_05/FastMC_install/bin/FastMC'
fmc_path = '/home/berbecolab/Software/gecco-master/extra/fastmc_install/bin/FastMC'

base_path = '/home/berbecolab/2-Datadir/Clinical_data/Head/'

nrrd_files = {
            '0':[base_path +'Patient_Head_Female_01.nrrd',[2,1,0],[None,None,None,None,None,None]],
            '1':[base_path +'Patient_Head_Female_02a.nrrd',[2,1,0],[None,None,None,None,None,None]],
            '2':[base_path +'Patient_Head_Female_03.nrrd',[2,0,1],[None,None,None,None,None,None]],
            '3':[base_path +'Patient_Head_Female_04.nrrd',[2,1,0],[None,None,None,None,None,None]],
            '4':[base_path +'Patient_Head_Female_05.nrrd',[2,1,0],[None,None,None,None,None,None]],
            '5':[base_path +'Patient_Head_Male_01.nrrd',[2,1,0],[None,None,None,None,None,None]],
            '6':[base_path +'Patient_Head_Male_02.nrrd',[2,1,0],[None,None,None,None,None,None]],
            '7':[base_path +'Patient_Head_Male_03.nrrd',[2,1,0],[None,None,None,None,None,None]],
            '8':[base_path +'Patient_Head_Male_04.nrrd',[2,1,0],[None,None,None,None,None,None]],
            '9':[base_path +'Patient_Head_Male_05.nrrd',[2,1,0],[None,None,None,None,None,None]],
            '10':[base_path +'Patient_Head_Male_06.nrrd',[2,1,0],[None,None,None,None,None,None]],
            '11':[base_path +'Patient_Head_Male_07.nrrd',[2,1,0],[None,None,None,None,None,None]],
            '12':[base_path +'Patient_Head_Male_08.nrrd',[2,1,0],[None,None,None,None,None,None]],
            '13':[base_path +'Patient_Head_Female_02b.nrrd',[2,1,0],[None,None,None,None,None,None]]}

# %%
file_index = '13' # File index to load

# %% [markdown]
# Crop the nrrd file

# %%
cropping_tool(nrrd_file=nrrd_files[file_index][0],tr=nrrd_files[file_index][1]) # Center on center of bladder
tr = nrrd_files[file_index][1]
crop = nrrd_files[file_index][2]
# Out:
# interactive(children=(IntSlider(value=0, description='x_start', max=183), IntSlider(value=183, description='x_…

# %% [markdown]
# Write to mhd

# %%
nrrd_to_mhd(nrrd_files[file_index][0],force=True,tr=tr,crop=crop) # crop=[-200,None,None,None,None,None]
# Out:
# [2024-06-06 11:48:05,985] {utils.py:687} INFO - Creating directory Patient_Head_Male_04
# [2024-06-06 11:48:06,755] {utils.py:764} INFO - Transposing the data
# [2024-06-06 11:48:06,756] {utils.py:766} INFO - The spacing is [1.25     0.847656 0.847656]
# [2024-06-06 11:48:06,757] {utils.py:768} INFO - The origin is [-100. -217. -217.]
# [2024-06-06 11:48:06,757] {utils.py:769} INFO - The shape is (176, 512, 512)
# [2024-06-06 11:48:06,884] {utils.py:743} INFO -     Processing HU section 0
# [2024-06-06 11:48:06,955] {utils.py:743} INFO -     Processing HU section 1
# [2024-06-06 11:48:07,010] {utils.py:743} INFO -     Processing HU section 2
# [2024-06-06 11:48:07,057] {utils.py:743} INFO -     Processing HU section 3
# [2024-06-06 11:48:07,110] {utils.py:743} INFO -     Processing HU section 4
# [2024-06-06 11:48:07,153] {utils.py:743} INFO -     Processing HU section 5
# [2024-06-06 11:48:07,196] {utils.py:743} INFO -     Processing HU section 6
# [2024-06-06 11:48:07,238] {utils.py:743} INFO -     Processing HU section 7
# [2024-06-06 11:48:07,290] {utils.py:743} INFO -     Processing HU section 8
# [2024-06-06 11:48:07,334] {utils.py:743} INFO -     Processing HU section 9
# [2024-06-06 11:48:07,379] {utils.py:743} INFO -     Processing HU section 10
# [2024-06-06 11:48:07,422] {utils.py:743} INFO -     Processing HU section 11
# [2024-06-06 11:48:07,465] {utils.py:743} INFO -     Processing HU section 12
# [2024-06-06 11:48:07,510] {utils.py:743} INFO -     Processing HU section 13
# [2024-06-06 11:48:07,550] {utils.py:743} INFO -     Processing HU section 14
# [2024-06-06 11:48:07,593] {utils.py:743} INFO -     Processing HU section 15
# [2024-06-06 11:48:07,637] {utils.py:743} INFO -     Processing HU section 16
# [2024-06-06 11:48:07,676] {utils.py:743} INFO -     Processing HU section 17
# [2024-06-06 11:48:07,716] {utils.py:743} INFO -     Processing HU section 18
# [2024-06-06 11:48:07,756] {utils.py:743} INFO -     Processing HU section 19
# [2024-06-06 11:48:07,795] {utils.py:743} INFO -     Processing HU section 20
# [2024-06-06 11:48:07,831] {utils.py:743} INFO -     Processing HU section 21
# [2024-06-06 11:48:07,868] {utils.py:743} INFO -     Processing HU section 22
# [2024-06-06 11:48:07,906] {utils.py:743} INFO -     Processing HU section 23
# [2024-06-06 11:48:07,942] {utils.py:743} INFO -     Processing HU section 24
# [2024-06-06 11:48:08,096] {utils.py:495} INFO - Loading density data from file
# [2024-06-06 11:48:08,099] {utils.py:984} INFO -     Saved SchneiderMaterialsWeight1 atten to file in data/mu_over_rho/SchneiderMaterialsWeight1.csv
# [2024-06-06 11:48:08,100] {utils.py:495} INFO - Loading density data from file
# [2024-06-06 11:48:08,104] {utils.py:984} INFO -     Saved SchneiderMaterialsWeight2 atten to file in data/mu_over_rho/SchneiderMaterialsWeight2.csv
# [2024-06-06 11:48:08,104] {utils.py:495} INFO - Loading density data from file
# [2024-06-06 11:48:08,108] {utils.py:984} INFO -     Saved SchneiderMaterialsWeight3 atten to file in data/mu_over_rho/SchneiderMaterialsWeight3.csv
# [2024-06-06 11:48:08,109] {utils.py:495} INFO - Loading density data from file
# [2024-06-06 11:48:08,112] {utils.py:984} INFO -     Saved SchneiderMaterialsWeight4 atten to file in data/mu_over_rho/SchneiderMaterialsWeight4.csv
# [2024-06-06 11:48:08,112] {utils.py:495} INFO - Loading density data from file
# [2024-06-06 11:48:08,115] {utils.py:984} INFO -     Saved SchneiderMaterialsWeight5 atten to file in data/mu_over_rho/SchneiderMaterialsWeight5.csv
# [2024-06-06 11:48:08,115] {utils.py:495} INFO - Loading density data from file
# [2024-06-06 11:48:08,120] {utils.py:984} INFO -     Saved SchneiderMaterialsWeight6 atten to file in data/mu_over_rho/SchneiderMaterialsWeight6.csv
# [2024-06-06 11:48:08,120] {utils.py:495} INFO - Loading density data from file
# [2024-06-06 11:48:08,123] {utils.py:984} INFO -     Saved SchneiderMaterialsWeight7 atten to file in data/mu_over_rho/SchneiderMaterialsWeight7.csv
# [2024-06-06 11:48:08,123] {utils.py:495} INFO - Loading density data from file
# [2024-06-06 11:48:08,126] {utils.py:984} INFO -     Saved SchneiderMaterialsWeight8 atten to file in data/mu_over_rho/SchneiderMaterialsWeight8.csv
# [2024-06-06 11:48:08,126] {utils.py:495} INFO - Loading density data from file
# [2024-06-06 11:48:08,129] {utils.py:984} INFO -     Saved SchneiderMaterialsWeight9 atten to file in data/mu_over_rho/SchneiderMaterialsWeight9.csv
# [2024-06-06 11:48:08,129] {utils.py:495} INFO - Loading density data from file
# [2024-06-06 11:48:08,133] {utils.py:984} INFO -     Saved SchneiderMaterialsWeight10 atten to file in data/mu_over_rho/SchneiderMaterialsWeight10.csv
# [2024-06-06 11:48:08,134] {utils.py:495} INFO - Loading density data from file
# [2024-06-06 11:48:08,137] {utils.py:984} INFO -     Saved SchneiderMaterialsWeight11 atten to file in data/mu_over_rho/SchneiderMaterialsWeight11.csv
# [2024-06-06 11:48:08,138] {utils.py:495} INFO - Loading density data from file
# [2024-06-06 11:48:08,141] {utils.py:984} INFO -     Saved SchneiderMaterialsWeight12 atten to file in data/mu_over_rho/SchneiderMaterialsWeight12.csv
# [2024-06-06 11:48:08,141] {utils.py:495} INFO - Loading density data from file
# [2024-06-06 11:48:08,143] {utils.py:984} INFO -     Saved SchneiderMaterialsWeight13 atten to file in data/mu_over_rho/SchneiderMaterialsWeight13.csv
# [2024-06-06 11:48:08,144] {utils.py:495} INFO - Loading density data from file
# [2024-06-06 11:48:08,146] {utils.py:984} INFO -     Saved SchneiderMaterialsWeight14 atten to file in data/mu_over_rho/SchneiderMaterialsWeight14.csv
# [2024-06-06 11:48:08,147] {utils.py:495} INFO - Loading density data from file
# [2024-06-06 11:48:08,150] {utils.py:984} INFO -     Saved SchneiderMaterialsWeight15 atten to file in data/mu_over_rho/SchneiderMaterialsWeight15.csv
# [2024-06-06 11:48:08,151] {utils.py:495} INFO - Loading density data from file
# [2024-06-06 11:48:08,154] {utils.py:984} INFO -     Saved SchneiderMaterialsWeight16 atten to file in data/mu_over_rho/SchneiderMaterialsWeight16.csv
# [2024-06-06 11:48:08,154] {utils.py:495} INFO - Loading density data from file
# [2024-06-06 11:48:08,157] {utils.py:984} INFO -     Saved SchneiderMaterialsWeight17 atten to file in data/mu_over_rho/SchneiderMaterialsWeight17.csv
# [2024-06-06 11:48:08,158] {utils.py:495} INFO - Loading density data from file
# [2024-06-06 11:48:08,160] {utils.py:984} INFO -     Saved SchneiderMaterialsWeight18 atten to file in data/mu_over_rho/SchneiderMaterialsWeight18.csv
# [2024-06-06 11:48:08,161] {utils.py:495} INFO - Loading density data from file
# [2024-06-06 11:48:08,163] {utils.py:984} INFO -     Saved SchneiderMaterialsWeight19 atten to file in data/mu_over_rho/SchneiderMaterialsWeight19.csv
# [2024-06-06 11:48:08,163] {utils.py:495} INFO - Loading density data from file
# [2024-06-06 11:48:08,169] {utils.py:984} INFO -     Saved SchneiderMaterialsWeight20 atten to file in data/mu_over_rho/SchneiderMaterialsWeight20.csv
# [2024-06-06 11:48:08,170] {utils.py:495} INFO - Loading density data from file
# [2024-06-06 11:48:08,176] {utils.py:984} INFO -     Saved SchneiderMaterialsWeight21 atten to file in data/mu_over_rho/SchneiderMaterialsWeight21.csv
# [2024-06-06 11:48:08,176] {utils.py:495} INFO - Loading density data from file
# [2024-06-06 11:48:08,181] {utils.py:984} INFO -     Saved SchneiderMaterialsWeight22 atten to file in data/mu_over_rho/SchneiderMaterialsWeight22.csv
# [2024-06-06 11:48:08,181] {utils.py:495} INFO - Loading density data from file
# [2024-06-06 11:48:08,186] {utils.py:984} INFO -     Saved SchneiderMaterialsWeight23 atten to file in data/mu_over_rho/SchneiderMaterialsWeight23.csv
# [2024-06-06 11:48:08,186] {utils.py:495} INFO - Loading density data from file
# [2024-06-06 11:48:08,190] {utils.py:984} INFO -     Saved SchneiderMaterialsWeight24 atten to file in data/mu_over_rho/SchneiderMaterialsWeight24.csv
# [2024-06-06 11:48:08,190] {utils.py:495} INFO - Loading density data from file
# [2024-06-06 11:48:08,194] {utils.py:984} INFO -     Saved SchneiderMaterialsWeight25 atten to file in data/mu_over_rho/SchneiderMaterialsWeight25.csv
# SchneiderMaterialsWeight1: d=0.0012 g/cm3 ; n=13;
# SchneiderMaterialsWeight2: d=0.4695 g/cm3 ; n=13;
# SchneiderMaterialsWeight3: d=0.0595 g/cm3 ; n=13;
# SchneiderMaterialsWeight4: d=0.9122 g/cm3 ; n=13;
# SchneiderMaterialsWeight5: d=0.9467 g/cm3 ; n=13;
# SchneiderMaterialsWeight6: d=0.9799 g/cm3 ; n=13;
# SchneiderMaterialsWeight7: d=1.0039 g/cm3 ; n=13;
# SchneiderMaterialsWeight8: d=1.0408 g/cm3 ; n=13;
# SchneiderMaterialsWeight9: d=1.0785 g/cm3 ; n=13;
# SchneiderMaterialsWeight10: d=1.1083 g/cm3 ; n=13;
# SchneiderMaterialsWeight11: d=1.1658 g/cm3 ; n=13;
# SchneiderMaterialsWeight12: d=1.2312 g/cm3 ; n=13;
# SchneiderMaterialsWeight13: d=1.2963 g/cm3 ; n=13;
# SchneiderMaterialsWeight14: d=1.3604 g/cm3 ; n=13;
# SchneiderMaterialsWeight15: d=1.4256 g/cm3 ; n=13;
# SchneiderMaterialsWeight16: d=1.4916 g/cm3 ; n=13;
# SchneiderMaterialsWeight17: d=1.5590 g/cm3 ; n=13;
# SchneiderMaterialsWeight18: d=1.6245 g/cm3 ; n=13;
# SchneiderMaterialsWeight19: d=1.6888 g/cm3 ; n=13;
# SchneiderMaterialsWeight20: d=1.7561 g/cm3 ; n=13;
# SchneiderMaterialsWeight21: d=1.8213 g/cm3 ; n=13;
# SchneiderMaterialsWeight22: d=1.8873 g/cm3 ; n=13;
# SchneiderMaterialsWeight23: d=1.9540 g/cm3 ; n=13;
# SchneiderMaterialsWeight24: d=2.4229 g/cm3 ; n=13;
# SchneiderMaterialsWeight25: d=4.5525 g/cm3 ; n=13;
# [2024-06-06 11:48:08,791] {utils.py:796} INFO - Phantom Created
# To load the phantom from the mhd file use the following command:
# phantom = patient_phantom.patient_phantom("/home/jericho/2-Datadir/Clinical_data/Head/Patient_Head_Male_04.nrrd",[nparticles])

# %% [markdown]
# Sample the phantom

# %%
phantom = patient_data.patient_phantom(nrrd_files[file_index][0], 1e6, force_materials=False, is_fullfan=False) #, reload=True, sim_num = 14)
# Out:
# [2024-06-06 11:48:09,003] {utils.py:185} INFO - Using default geometry, DSD = 1510, nDetector = [512, 512], dDetector = [0.784, 0.784]
# [2024-06-06 11:48:09,004] {utils.py:495} INFO - Loading density data from file
# [2024-06-06 11:48:09,005] {utils.py:551} INFO - Loading attenuation files from /home/jericho/Software/gecco/gecco/data/user_phantoms/Patient_Head_Male_04/Patient_Head_Male_04_materials.txt
# [2024-06-06 11:48:09,005] {utils.py:552} INFO - Making attenuation files in gecco:
# [2024-06-06 11:48:09,005] {utils.py:556} INFO -     Air atten file already exists, skipping...
# [2024-06-06 11:48:09,006] {utils.py:556} INFO -     polyurethane atten file already exists, skipping...
# [2024-06-06 11:48:09,006] {utils.py:556} INFO -     teflon atten file already exists, skipping...
# [2024-06-06 11:48:09,006] {utils.py:556} INFO -     pmp atten file already exists, skipping...
# [2024-06-06 11:48:09,006] {utils.py:556} INFO -     bone50 atten file already exists, skipping...
# [2024-06-06 11:48:09,006] {utils.py:556} INFO -     ldpe atten file already exists, skipping...
# [2024-06-06 11:48:09,006] {utils.py:556} INFO -     polystyrene atten file already exists, skipping...
# [2024-06-06 11:48:09,007] {utils.py:556} INFO -     acrylic atten file already exists, skipping...
# [2024-06-06 11:48:09,007] {utils.py:556} INFO -     bone20 atten file already exists, skipping...
# [2024-06-06 11:48:09,007] {utils.py:556} INFO -     pom atten file already exists, skipping...
# [2024-06-06 11:48:09,007] {utils.py:556} INFO -     Tungsten atten file already exists, skipping...
# [2024-06-06 11:48:09,008] {utils.py:556} INFO -     GOS atten file already exists, skipping...
# [2024-06-06 11:48:09,008] {utils.py:556} INFO -     CsI atten file already exists, skipping...
# [2024-06-06 11:48:09,008] {utils.py:556} INFO -     Aluminium atten file already exists, skipping...
# [2024-06-06 11:48:09,008] {utils.py:556} INFO -     Copper atten file already exists, skipping...
# [2024-06-06 11:48:09,008] {utils.py:556} INFO -     SchneiderMaterialsWeight1 atten file already exists, skipping...
# [2024-06-06 11:48:09,009] {utils.py:556} INFO -     SchneiderMaterialsWeight2 atten file already exists, skipping...
# [2024-06-06 11:48:09,009] {utils.py:556} INFO -     SchneiderMaterialsWeight3 atten file already exists, skipping...
# [2024-06-06 11:48:09,009] {utils.py:556} INFO -     SchneiderMaterialsWeight4 atten file already exists, skipping...
# [2024-06-06 11:48:09,009] {utils.py:556} INFO -     SchneiderMaterialsWeight5 atten file already exists, skipping...
# [2024-06-06 11:48:09,009] {utils.py:556} INFO -     SchneiderMaterialsWeight6 atten file already exists, skipping...
# [2024-06-06 11:48:09,010] {utils.py:556} INFO -     SchneiderMaterialsWeight7 atten file already exists, skipping...
# [2024-06-06 11:48:09,010] {utils.py:556} INFO -     SchneiderMaterialsWeight8 atten file already exists, skipping...
# [2024-06-06 11:48:09,010] {utils.py:556} INFO -     SchneiderMaterialsWeight9 atten file already exists, skipping...
# [2024-06-06 11:48:09,011] {utils.py:556} INFO -     SchneiderMaterialsWeight10 atten file already exists, skipping...
# [2024-06-06 11:48:09,011] {utils.py:556} INFO -     SchneiderMaterialsWeight11 atten file already exists, skipping...
# [2024-06-06 11:48:09,011] {utils.py:556} INFO -     SchneiderMaterialsWeight12 atten file already exists, skipping...
# [2024-06-06 11:48:09,011] {utils.py:556} INFO -     SchneiderMaterialsWeight13 atten file already exists, skipping...
# [2024-06-06 11:48:09,012] {utils.py:556} INFO -     SchneiderMaterialsWeight14 atten file already exists, skipping...
# [2024-06-06 11:48:09,012] {utils.py:556} INFO -     SchneiderMaterialsWeight15 atten file already exists, skipping...
# [2024-06-06 11:48:09,012] {utils.py:556} INFO -     SchneiderMaterialsWeight16 atten file already exists, skipping...
# [2024-06-06 11:48:09,012] {utils.py:556} INFO -     SchneiderMaterialsWeight17 atten file already exists, skipping...
# [2024-06-06 11:48:09,012] {utils.py:556} INFO -     SchneiderMaterialsWeight18 atten file already exists, skipping...
# [2024-06-06 11:48:09,013] {utils.py:556} INFO -     SchneiderMaterialsWeight19 atten file already exists, skipping...
# [2024-06-06 11:48:09,013] {utils.py:556} INFO -     SchneiderMaterialsWeight20 atten file already exists, skipping...
# [2024-06-06 11:48:09,013] {utils.py:556} INFO -     SchneiderMaterialsWeight21 atten file already exists, skipping...
# [2024-06-06 11:48:09,013] {utils.py:556} INFO -     SchneiderMaterialsWeight22 atten file already exists, skipping...
# [2024-06-06 11:48:09,013] {utils.py:556} INFO -     SchneiderMaterialsWeight23 atten file already exists, skipping...
# [2024-06-06 11:48:09,013] {utils.py:556} INFO -     SchneiderMaterialsWeight24 atten file already exists, skipping...
# [2024-06-06 11:48:09,014] {utils.py:556} INFO -     SchneiderMaterialsWeight25 atten file already exists, skipping...
# [2024-06-06 11:48:09,014] {patient_data.py:120} INFO - Half fan mode
# [2024-06-06 11:48:09,015] {patient_data.py:121} INFO -     Bowtie file: /home/jericho/Software/gecco/gecco/data/bowties/half_fan_mm.dat
# [2024-06-06 11:48:09,015] {patient_data.py:122} INFO -     Detector offset: [   0 -160]
# [2024-06-06 11:48:09,015] {patient_data.py:125} INFO - Patient phantom loaded
# [2024-06-06 11:48:09,015] {patient_data.py:126} INFO -     Nrrd file: /home/jericho/2-Datadir/Clinical_data/Head/Patient_Head_Male_04.nrrd
# [2024-06-06 11:48:09,016] {patient_data.py:127} INFO -     Number of particles: 1000000.0
# [2024-06-06 11:48:09,016] {patient_data.py:129} INFO -     Full fan mode: False
# [2024-06-06 11:48:09,016] {patient_data.py:130} INFO - To intialize fastmc simulation of this phantom use phantom.initialize_fastmc([number of angles],[spectrum])
# [2024-06-06 11:48:09,016] {patient_data.py:132} INFO - To make a spectrum object using spekpy: spectrum = spectrum.calculate_spectrum_sp([kvp], [anode angle])
# [2024-06-06 11:48:09,017] {patient_data.py:134} INFO - Additional filtration can be added like spectrum.filter("Al", 4) # 4 mm Al filtration

# %% [markdown]
# Plot one slice: Make sure it is axial

# %%
plt.figure()
plt.imshow(phantom.phantom[phantom.phantom.shape[0]//2,:,:])

# %% [markdown]
# ## Write all the files
#
# This is into a test directory

# %%
for key,nrrd in nrrd_files.items():
    print(key + ' : ' + nrrd[0])

    test_file_name = nrrd[0].split('/')[-1].split('.')[0] + '_test.py'
    test_sim_dir = './test_python_scripts/'

    write_python_script_head(nrrd[0],os.path.join(test_sim_dir,test_file_name),tr=nrrd[1],crop=nrrd[2],nphoton=1e6,fast_mc_path=fmc_path)

# Combine the current working directory with the test_sim_dir
test_sim_dir_abs = os.path.join(os.getcwd(),test_sim_dir)
write_run_all_script(test_sim_dir_abs)

# Make the script executable
# !chmod +x ./test_python_scripts/run_all.sh
# Out:
# 0 : /home/berbecolab/2-Datadir/Clinical_data/Head/Patient_Head_Female_01.nrrd
# 1 : /home/berbecolab/2-Datadir/Clinical_data/Head/Patient_Head_Female_02a.nrrd
# 2 : /home/berbecolab/2-Datadir/Clinical_data/Head/Patient_Head_Female_03.nrrd
# 3 : /home/berbecolab/2-Datadir/Clinical_data/Head/Patient_Head_Female_04.nrrd
# 4 : /home/berbecolab/2-Datadir/Clinical_data/Head/Patient_Head_Female_05.nrrd
# 5 : /home/berbecolab/2-Datadir/Clinical_data/Head/Patient_Head_Male_01.nrrd
# 6 : /home/berbecolab/2-Datadir/Clinical_data/Head/Patient_Head_Male_02.nrrd
# 7 : /home/berbecolab/2-Datadir/Clinical_data/Head/Patient_Head_Male_03.nrrd
# 8 : /home/berbecolab/2-Datadir/Clinical_data/Head/Patient_Head_Male_04.nrrd
# 9 : /home/berbecolab/2-Datadir/Clinical_data/Head/Patient_Head_Male_05.nrrd
# 10 : /home/berbecolab/2-Datadir/Clinical_data/Head/Patient_Head_Male_06.nrrd
# 11 : /home/berbecolab/2-Datadir/Clinical_data/Head/Patient_Head_Male_07.nrrd
# 12 : /home/berbecolab/2-Datadir/Clinical_data/Head/Patient_Head_Male_08.nrrd
# 13 : /home/berbecolab/2-Datadir/Clinical_data/Head/Patient_Head_Female_02b.nrrd
# [2024-06-06 15:00:25,531] {utils.py:1020} INFO - Script written to run all Python files in the directory

# %% [markdown]
# ## Write all files
#
# This is to the run directory

# %%
for key, nrrd in nrrd_files.items():
    print(key + ' : ' + nrrd[0])

    file_name = nrrd[0].split('/')[-1].split('.')[0] + '.py'
    sim_dir = './python_scripts/'

    write_python_script_head(nrrd[0], os.path.join(sim_dir,file_name),tr=nrrd[1],crop=nrrd[2],nphoton=1e10,fast_mc_path=fmc_path)

# Combine the current working directory with the test_sim_dir
test_sim_dir_abs = os.path.join(os.getcwd(),sim_dir)
write_run_all_script(test_sim_dir_abs)

# Make the script executable
# !chmod +x ./python_scripts/run_all.sh
# Out:
# 0 : /home/berbecolab/2-Datadir/Clinical_data/Head/Patient_Head_Female_01.nrrd
# 1 : /home/berbecolab/2-Datadir/Clinical_data/Head/Patient_Head_Female_02a.nrrd
# 2 : /home/berbecolab/2-Datadir/Clinical_data/Head/Patient_Head_Female_03.nrrd
# 3 : /home/berbecolab/2-Datadir/Clinical_data/Head/Patient_Head_Female_04.nrrd
# 4 : /home/berbecolab/2-Datadir/Clinical_data/Head/Patient_Head_Female_05.nrrd
# 5 : /home/berbecolab/2-Datadir/Clinical_data/Head/Patient_Head_Male_01.nrrd
# 6 : /home/berbecolab/2-Datadir/Clinical_data/Head/Patient_Head_Male_02.nrrd
# 7 : /home/berbecolab/2-Datadir/Clinical_data/Head/Patient_Head_Male_03.nrrd
# 8 : /home/berbecolab/2-Datadir/Clinical_data/Head/Patient_Head_Male_04.nrrd
# 9 : /home/berbecolab/2-Datadir/Clinical_data/Head/Patient_Head_Male_05.nrrd
# 10 : /home/berbecolab/2-Datadir/Clinical_data/Head/Patient_Head_Male_06.nrrd
# 11 : /home/berbecolab/2-Datadir/Clinical_data/Head/Patient_Head_Male_07.nrrd
# 12 : /home/berbecolab/2-Datadir/Clinical_data/Head/Patient_Head_Male_08.nrrd
# 13 : /home/berbecolab/2-Datadir/Clinical_data/Head/Patient_Head_Female_02b.nrrd
# [2024-06-06 15:00:28,227] {utils.py:1020} INFO - Script written to run all Python files in the directory
