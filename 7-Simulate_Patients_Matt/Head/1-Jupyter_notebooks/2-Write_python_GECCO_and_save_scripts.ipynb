# %%
# %matplotlib inline
# %load_ext autoreload
# %autoreload 2

# %%
# Read the mhd file from data
import os
import matplotlib.pyplot as plt

import mpl_interactions as pli
from gecco import patient_data
import gecco as fc
import numpy as np
from gecco.utils import nrrd_to_mhd, cropping_tool
# Out:
# [2024-06-06 14:50:12,587] {utils.py:148} INFO - Note: NumExpr detected 32 cores but "NUMEXPR_MAX_THREADS" not set, so enforcing safe limit of 8.
# [2024-06-06 14:50:12,587] {utils.py:160} INFO - NumExpr defaulting to 8 threads.

# %% [markdown]
# ## This script generates the rest of the code to run batch GECCO simulations
#
# The first few cells are to check the simulation density and phantom are aligned, manually
#
# Modify the dictionary so that the last integer specifies the right simulation to load for each of the simulations
#
# ## Running the GECCO sims
#
# The last few cells generate the scripts for running the simulations
#
# Best to make a test output directory with only 2 projections
#
# From there create the full simulations

# %%
# Number : [path, orientation, crop]
# fmc_path = '/home/jericho/Downloads/FastMC_Jan_05/FastMC_install/bin/FastMC'
fmc_path = '/home/berbecolab/Software/gecco-master/extra/fastmc_install/bin/FastMC'

base_path = '/home/berbecolab/2-Datadir/Clinical_data/Head/'

nrrd_files = {
            '0':[base_path +'Patient_Head_Female_01.nrrd',[2,1,0],[None,None,None,None,None,None],None],
            '1':[base_path +'Patient_Head_Female_02a.nrrd',[2,1,0],[None,None,None,None,None,None],None],
            '2':[base_path +'Patient_Head_Female_03.nrrd',[2,0,1],[None,None,None,None,None,None],None],
            '3':[base_path +'Patient_Head_Female_04.nrrd',[2,1,0],[None,None,None,None,None,None],None],
            '4':[base_path +'Patient_Head_Female_05.nrrd',[2,1,0],[None,None,None,None,None,None],None],
            '5':[base_path +'Patient_Head_Male_01.nrrd',[2,1,0],[None,None,None,None,None,None],None],
            '6':[base_path +'Patient_Head_Male_02.nrrd',[2,1,0],[None,None,None,None,None,None],None],
            '7':[base_path +'Patient_Head_Male_03.nrrd',[2,1,0],[None,None,None,None,None,None],None],
            '8':[base_path +'Patient_Head_Male_04.nrrd',[2,1,0],[None,None,None,None,None,None],None],
            '9':[base_path +'Patient_Head_Male_05.nrrd',[2,1,0],[None,None,None,None,None,None],None],
            '10':[base_path +'Patient_Head_Male_06.nrrd',[2,1,0],[None,None,None,None,None,None],None],
            '11':[base_path +'Patient_Head_Male_07.nrrd',[2,1,0],[None,None,None,None,None,None],None],
            '12':[base_path +'Patient_Head_Male_08.nrrd',[2,1,0],[None,None,None,None,None,None],None],
            '13':[base_path +'Patient_Head_Female_02b.nrrd',[2,1,0],[None,None,None,None,None,None],None]}

# %%
file_index = '0'

# %% [markdown]
# ## Load the simulation

# %%
nrrd_file = nrrd_files[file_index][0]
sim_num = nrrd_files[file_index][3]

# %%
phantom = patient_data.patient_phantom(nrrd_file, 1e10, reload=True, sim_num=sim_num)
# Out:
# [2024-06-07 10:29:56,729] {patient_data.py:69} INFO - Reloading phantom
# [2024-06-07 10:29:56,729] {patient_data.py:154} INFO - Found existing directory. Using mhd file Patient_Head_Female_01_phantom.mhd
# [2024-06-07 10:29:56,798] {patient_data.py:184} INFO - Phantom loaded from pickle file fastmc_1e10_10angles.pkl
# [2024-06-07 10:29:56,839] {patient_data.py:190} INFO - Loading ggems files
#
# [2024-06-07 10:29:56,840] {patient_data.py:221} INFO - Using the first detector layer ggems files
# [2024-06-07 10:29:56,921] {patient_data.py:259} INFO - ggems files loaded
# [2024-06-07 10:29:56,921] {patient_data.py:260} INFO -     Scatter files:
# [2024-06-07 10:29:56,921] {patient_data.py:263} INFO -         /home/berbecolab/Software/gecco-master/gecco/data/user_phantoms/Patient_Head_Female_01/fastmc_output/fastmc_0.00-scatter.mhd
# [2024-06-07 10:29:56,921] {patient_data.py:265} INFO -           Shape:(360, 360)
# [2024-06-07 10:29:56,921] {patient_data.py:263} INFO -         /home/berbecolab/Software/gecco-master/gecco/data/user_phantoms/Patient_Head_Female_01/fastmc_output/fastmc_108.00-scatter.mhd
# [2024-06-07 10:29:56,921] {patient_data.py:265} INFO -           Shape:(360, 360)
# [2024-06-07 10:29:56,922] {patient_data.py:263} INFO -         /home/berbecolab/Software/gecco-master/gecco/data/user_phantoms/Patient_Head_Female_01/fastmc_output/fastmc_144.00-scatter.mhd
# [2024-06-07 10:29:56,922] {patient_data.py:265} INFO -           Shape:(360, 360)
# [2024-06-07 10:29:56,922] {patient_data.py:263} INFO -         /home/berbecolab/Software/gecco-master/gecco/data/user_phantoms/Patient_Head_Female_01/fastmc_output/fastmc_180.00-scatter.mhd
# [2024-06-07 10:29:56,922] {patient_data.py:265} INFO -           Shape:(360, 360)
# [2024-06-07 10:29:56,922] {patient_data.py:263} INFO -         /home/berbecolab/Software/gecco-master/gecco/data/user_phantoms/Patient_Head_Female_01/fastmc_output/fastmc_216.00-scatter.mhd
# [2024-06-07 10:29:56,922] {patient_data.py:265} INFO -           Shape:(360, 360)
# [2024-06-07 10:29:56,922] {patient_data.py:263} INFO -         /home/berbecolab/Software/gecco-master/gecco/data/user_phantoms/Patient_Head_Female_01/fastmc_output/fastmc_252.00-scatter.mhd
# [2024-06-07 10:29:56,922] {patient_data.py:265} INFO -           Shape:(360, 360)
# [2024-06-07 10:29:56,923] {patient_data.py:263} INFO -         /home/berbecolab/Software/gecco-master/gecco/data/user_phantoms/Patient_Head_Female_01/fastmc_output/fastmc_288.00-scatter.mhd
# [2024-06-07 10:29:56,923] {patient_data.py:265} INFO -           Shape:(360, 360)
# [2024-06-07 10:29:56,923] {patient_data.py:263} INFO -         /home/berbecolab/Software/gecco-master/gecco/data/user_phantoms/Patient_Head_Female_01/fastmc_output/fastmc_324.00-scatter.mhd
# [2024-06-07 10:29:56,923] {patient_data.py:265} INFO -           Shape:(360, 360)
# [2024-06-07 10:29:56,923] {patient_data.py:263} INFO -         /home/berbecolab/Software/gecco-master/gecco/data/user_phantoms/Patient_Head_Female_01/fastmc_output/fastmc_36.00-scatter.mhd
# [2024-06-07 10:29:56,923] {patient_data.py:265} INFO -           Shape:(360, 360)
# [2024-06-07 10:29:56,923] {patient_data.py:263} INFO -         /home/berbecolab/Software/gecco-master/gecco/data/user_phantoms/Patient_Head_Female_01/fastmc_output/fastmc_72.00-scatter.mhd
# [2024-06-07 10:29:56,923] {patient_data.py:265} INFO -           Shape:(360, 360)

# %% [markdown]
# ## Check the alignment of the density and the phantom

# %%
plt.figure(figsize=[10,6])
plt.subplot(121)
plt.imshow(np.flipud(phantom.phantom[40,:,:]),cmap='gray',aspect='equal')
plt.axis('off')
plt.subplot(122)
plt.imshow(np.flipud(phantom.density[40,:,:]),cmap='gray',aspect='equal')
plt.axis('off')
plt.tight_layout()

# %%
# Source spectrum
spectrum = fc.calculate_spectrum_sp(125,12)

# phantom.phantom = np.flip(phantom.phantom,axis=[2])
# Beam filters
spectrum.filter('Be', 1.5)
spectrum.filter('Al', 2.75)
spectrum.filter('Ti', 0.89)

# Detector filters
spectrum.filter('Al', 3.7)
spectrum.filter('C', 3.8*(2/1.7)) # Difference in density

phantom.xx, phantom.yy = spectrum.get_points()
phantom.run_gecco(1e20,360,conv_on=False)
# Out:
# [2024-06-07 10:42:17,653] {patient_data.py:609} INFO - Making a list of angles
# [2024-06-07 10:42:17,653] {patient_data.py:637} INFO - Detector matching specifications: CsI-784-micrometer
# [2024-06-07 10:42:17,656] {ggems_simulate.py:204} INFO - Initializing filter /home/berbecolab/Software/gecco-master/gecco/data/bowties/full_fan_alt.dat
# [2024-06-07 10:42:17,857] {ggems_simulate.py:581} INFO - Running Simulations: 360 Projections
# [2024-06-07 10:42:17,857] {ggems_simulate.py:609} INFO -     Simulating 10 keV
# [2024-06-07 10:42:17,869] {ggems_simulate.py:688} INFO -         Attenuation at 10 keV for SchneiderMaterialsWeight2 is 10.349854284535223
# [2024-06-07 10:42:17,873] {ggems_simulate.py:688} INFO -         Attenuation at 10 keV for SchneiderMaterialsWeight3 is 5.647085846302243
# [2024-06-07 10:42:17,878] {ggems_simulate.py:688} INFO -         Attenuation at 10 keV for SchneiderMaterialsWeight4 is 6.434291404998359
# [2024-06-07 10:42:17,884] {ggems_simulate.py:688} INFO -         Attenuation at 10 keV for SchneiderMaterialsWeight5 is 7.41921156863626
# [2024-06-07 10:42:17,891] {ggems_simulate.py:688} INFO -         Attenuation at 10 keV for SchneiderMaterialsWeight6 is 8.095364893784069
# [2024-06-07 10:42:17,895] {ggems_simulate.py:688} INFO -         Attenuation at 10 keV for SchneiderMaterialsWeight7 is 8.720498132107027
# [2024-06-07 10:42:17,906] {ggems_simulate.py:688} INFO -         Attenuation at 10 keV for SchneiderMaterialsWeight8 is 9.987872420657736
# [2024-06-07 10:42:17,913] {ggems_simulate.py:688} INFO -         Attenuation at 10 keV for SchneiderMaterialsWeight9 is 9.558656996285107
# [2024-06-07 10:42:17,917] {ggems_simulate.py:688} INFO -         Attenuation at 10 keV for SchneiderMaterialsWeight10 is 15.423903780826354
# [2024-06-07 10:42:17,920] {ggems_simulate.py:688} INFO -         Attenuation at 10 keV for SchneiderMaterialsWeight11 is 19.070801577351165
# [2024-06-07 10:42:17,923] {ggems_simulate.py:688} INFO -         Attenuation at 10 keV for SchneiderMaterialsWeight12 is 22.728648120522084
# [2024-06-07 10:42:17,925] {ggems_simulate.py:688} INFO -         Attenuation at 10 keV for SchneiderMaterialsWeight13 is 26.136337734310267
# [2024-06-07 10:42:17,927] {ggems_simulate.py:688} INFO -         Attenuation at 10 keV for SchneiderMaterialsWeight14 is 29.074337134990003
# [2024-06-07 10:42:17,929] {ggems_simulate.py:688} INFO -         Attenuation at 10 keV for SchneiderMaterialsWeight15 is 31.9503293211462
# [2024-06-07 10:42:17,931] {ggems_simulate.py:688} INFO -         Attenuation at 10 keV for SchneiderMaterialsWeight16 is 34.599218543378306
# [2024-06-07 10:42:17,934] {ggems_simulate.py:688} INFO -         Attenuation at 10 keV for SchneiderMaterialsWeight17 is 37.202001617946955
# [2024-06-07 10:42:17,936] {ggems_simulate.py:688} INFO -         Attenuation at 10 keV for SchneiderMaterialsWeight18 is 39.310105339027345
# [2024-06-07 10:42:17,938] {ggems_simulate.py:688} INFO -         Attenuation at 10 keV for SchneiderMaterialsWeight19 is 41.40720433274653
# [2024-06-07 10:42:17,941] {ggems_simulate.py:688} INFO -         Attenuation at 10 keV for SchneiderMaterialsWeight20 is 43.50158703487016
# [2024-06-07 10:42:17,943] {ggems_simulate.py:688} INFO -         Attenuation at 10 keV for SchneiderMaterialsWeight21 is 45.220248308135865
# [2024-06-07 10:42:17,946] {ggems_simulate.py:688} INFO -         Attenuation at 10 keV for SchneiderMaterialsWeight22 is 46.93204892871713
# [2024-06-07 10:42:17,948] {ggems_simulate.py:688} INFO -         Attenuation at 10 keV for SchneiderMaterialsWeight23 is 48.63699096984875
# [2024-06-07 10:42:17,950] {ggems_simulate.py:688} INFO -         Attenuation at 10 keV for SchneiderMaterialsWeight24 is 49.80115831094798
# [2024-06-07 10:42:17,952] {ggems_simulate.py:688} INFO -         Attenuation at 10 keV for SchneiderMaterialsWeight25 is 185.91657459875418
# [2024-06-07 10:42:18,443] {ggems_simulate.py:714} INFO -       Phantom is_patient: True, using density correction
# [2024-06-07 10:42
{ggems_simulate.py:688} INFO -         Attenuation at 90 keV for SchneiderMaterialsWeight20 is 0.1983146246620495
# [2024-06-07 10:42:22,888] {ggems_simulate.py:688} INFO -         Attenuation at 90 keV for SchneiderMaterialsWeight21 is 0.19945349432996706
# [2024-06-07 10:42:22,891] {ggems_simulate.py:688} INFO -         Attenuation at 90 keV for SchneiderMaterialsWeight22 is 0.20058651508008535
# [2024-06-07 10:42:22,893] {ggems_simulate.py:688} INFO -         Attenuation at 90 keV for SchneiderMaterialsWeight23 is 0.2017137064206372
# [2024-06-07 10:42:22,895] {ggems_simulate.py:688} INFO -         Attenuation at 90 keV for SchneiderMaterialsWeight24 is 0.2024854128608931
# [2024-06-07 10:42:22,896] {ggems_simulate.py:688} INFO -         Attenuation at 90 keV for SchneiderMaterialsWeight25 is 0.3293170096838773
# [2024-06-07 10:42:23,353] {ggems_simulate.py:714} INFO -       Phantom is_patient: True, using density correction
# [2024-06-07 10:42:23,406] {ggems_simulate.py:609} INFO -     Simulating 100 keV
# [2024-06-07 10:42:23,417] {ggems_simulate.py:688} INFO -         Attenuation at 100 keV for SchneiderMaterialsWeight2 is 0.1515021179976998
# [2024-06-07 10:42:23,422] {ggems_simulate.py:688} INFO -         Attenuation at 100 keV for SchneiderMaterialsWeight3 is 0.1519426988340516
# [2024-06-07 10:42:23,426] {ggems_simulate.py:688} INFO -         Attenuation at 100 keV for SchneiderMaterialsWeight4 is 0.15176382374972636
# [2024-06-07 10:42:23,432] {ggems_simulate.py:688} INFO -         Attenuation at 100 keV for SchneiderMaterialsWeight5 is 0.15163111172513627
# [2024-06-07 10:42:23,438] {ggems_simulate.py:688} INFO -         Attenuation at 100 keV for SchneiderMaterialsWeight6 is 0.1515598644801157
# [2024-06-07 10:42:23,443] {ggems_simulate.py:688} INFO -         Attenuation at 100 keV for SchneiderMaterialsWeight7 is 0.15146850654917182
# [2024-06-07 10:42:23,453] {ggems_simulate.py:688} INFO -         Attenuation at 100 keV for SchneiderMaterialsWeight8 is 0.1514060898855768
# [2024-06-07 10:42:23,459] {ggems_simulate.py:688} INFO -         Attenuation at 100 keV for SchneiderMaterialsWeight9 is 0.15007622935743054
# [2024-06-07 10:42:23,464] {ggems_simulate.py:688} INFO -         Attenuation at 100 keV for SchneiderMaterialsWeight10 is 0.1520393087469352
# [2024-06-07 10:42:23,466] {ggems_simulate.py:688} INFO -         Attenuation at 100 keV for SchneiderMaterialsWeight11 is 0.15232346291098847
# [2024-06-07 10:42:23,469] {ggems_simulate.py:688} INFO -         Attenuation at 100 keV for SchneiderMaterialsWeight12 is 0.15247703627633247
# [2024-06-07 10:42:23,471] {ggems_simulate.py:688} INFO -         Attenuation at 100 keV for SchneiderMaterialsWeight13 is 0.15268934471339574
# [2024-06-07 10:42:23,473] {ggems_simulate.py:688} INFO -         Attenuation at 100 keV for SchneiderMaterialsWeight14 is 0.15290292056760196
# [2024-06-07 10:42:23,475] {ggems_simulate.py:688} INFO -         Attenuation at 100 keV for SchneiderMaterialsWeight15 is 0.15308852375685347
# [2024-06-07 10:42:23,477] {ggems_simulate.py:688} INFO -         Attenuation at 100 keV for SchneiderMaterialsWeight16 is 0.15320956661385046
# [2024-06-07 10:42:23,480] {ggems_simulate.py:688} INFO -         Attenuation at 100 keV for SchneiderMaterialsWeight17 is 0.15330961712167118
# [2024-06-07 10:42:23,482] {ggems_simulate.py:688} INFO -         Attenuation at 100 keV for SchneiderMaterialsWeight18 is 0.15340046766628238
# [2024-06-07 10:42:23,484] {ggems_simulate.py:688} INFO -         Attenuation at 100 keV for SchneiderMaterialsWeight19 is 0.15362032395280917
# [2024-06-07 10:42:23,487] {ggems_simulate.py:688} INFO -         Attenuation at 100 keV for SchneiderMaterialsWeight20 is 0.1537066363423544
# [2024-06-07 10:42:23,489] {ggems_simulate.py:688} INFO -         Attenuation at 100 keV for SchneiderMaterialsWeight21 is 0.15381488563545123
# [2024-06-07 10:42:23,492] {ggems_simulate.py:688} INFO -         Attenuation at 100 keV for SchneiderMaterialsWeight22 is 0.15392100051609414
# [2024-06-07 10:42:23,494] {ggems_simulate.py:688} INFO -         Attenuation at 100 keV for SchneiderMaterialsWeight23 is 0.15402498444419202
# [2024-06-07 10:42:23,496] {ggems_simulate.py:688} INFO -         Attenuation at 100 keV for SchneiderMaterialsWeight24 is 0.15410025505490138
# [2024-06-07 10:42:23,497] {ggems_simulate.py:688} INFO -         Attenuation at 100 keV for SchneiderMaterialsWeight25 is 0.18529688526447843
# [2024-06-07 10:42:23,955] {ggems_simulate.py:714} INFO -       Phantom is_patient: True, using density correction
# [2024-06-07 10:42:24,009] {ggems_simulate.py:873} INFO - Weighting simulations
# [2024-06-07 10:42:25,563] {ggems_simulate.py:916} INFO - Simulation Finished
# [2024-06-07 10:42:25,564] {ggems_simulate.py:917} INFO -     Analytical projections are stored as: phantom.primary_projections
# [2024-06-07 10:42:25,564] {ggems_simulate.py:919} INFO -     Analytical flood field are stored as: phantom.flood_field

# %%
plt.figure()
plt.imshow(phantom.flood_field)

plt.figure()
plt.plot(phantom.ggems_scatter_denoised[0,150])
plt.plot(phantom.primary_projections[0,150])

# %%
phantom.correct_intensity(ml=False,crop=40)
# phantom.sim_angles = np.linspace(0,2*np.pi,10)
phantom.interpolate_ggems_scatter()
phantom.calc_gecco_projections(scat_weight=0.4,noise_weight=100) # Creates the gecco projections scatter to primary reduction from asg is 0.48 assumed half is taken by scatter correction
# phantom.add_poisson_noise(0.5)
phantom.reconstruct_ggems(algo="FDK",filt='ram_lak')

# %%
plt.figure(figsize=[10,6])
plt.subplot(121)
plt.imshow(np.flipud(phantom.img[40,:,:]),cmap='gray',aspect='equal',vmin=np.percentile(phantom.img[40],40),vmax=np.percentile(phantom.img[40],98))
# plt.title('GECCO CBCT')
plt.axis('off')
plt.subplot(122)
plt.imshow(np.flipud(phantom.density[40,:,:]),cmap='gray',aspect='equal',vmin=np.percentile(phantom.density[40],40),vmax=np.percentile(phantom.density[40],98))
# plt.title('Clinical CT')
plt.axis('off')
plt.tight_layout()

# %% [markdown]
# ## Second layer

# %%
phantom = patient_data.patient_phantom(nrrd_file, 1e10, reload=True, sim_num=sim_num, second_layer=True)
# Out:
# [2024-06-07 10:42:28,158] {patient_data.py:69} INFO - Reloading phantom
# [2024-06-07 10:42:28,159] {patient_data.py:154} INFO - Found existing directory. Using mhd file Patient_Head_Female_01_phantom.mhd
# [2024-06-07 10:42:28,217] {patient_data.py:184} INFO - Phantom loaded from pickle file fastmc_1e10_10angles.pkl
# [2024-06-07 10:42:28,252] {patient_data.py:190} INFO - Loading ggems files
#
# [2024-06-07 10:42:28,252] {patient_data.py:214} INFO - Using the second detector layer ggems files
# [2024-06-07 10:42:28,328] {patient_data.py:259} INFO - ggems files loaded
# [2024-06-07 10:42:28,328] {patient_data.py:260} INFO -     Scatter files:
# [2024-06-07 10:42:28,328] {patient_data.py:263} INFO -         /home/berbecolab/Software/gecco-master/gecco/data/user_phantoms/Patient_Head_Female_01/fastmc_output/fastmc_0.00_2-scatter.mhd
# [2024-06-07 10:42:28,329] {patient_data.py:265} INFO -           Shape:(360, 360)
# [2024-06-07 10:42:28,329] {patient_data.py:263} INFO -         /home/berbecolab/Software/gecco-master/gecco/data/user_phantoms/Patient_Head_Female_01/fastmc_output/fastmc_108.00_2-scatter.mhd
# [2024-06-07 10:42:28,329] {patient_data.py:265} INFO -           Shape:(360, 360)
# [2024-06-07 10:42:28,329] {patient_data.py:263} INFO -         /home/berbecolab/Software/gecco-master/gecco/data/user_phantoms/Patient_Head_Female_01/fastmc_output/fastmc_144.00_2-scatter.mhd
# [2024-06-07 10:42:28,329] {patient_data.py:265} INFO -           Shape:(360, 360)
# [2024-06-07 10:42:28,330] {patient_data.py:263} INFO -         /home/berbecolab/Software/gecco-master/gecco/data/user_phantoms/Patient_Head_Female_01/fastmc_output/fastmc_180.00_2-scatter.mhd
# [2024-06-07 10:42:28,330] {patient_data.py:265} INFO -           Shape:(360, 360)
# [2024-06-07 10:42:28,330] {patient_data.py:263} INFO -         /home/berbecolab/Software/gecco-master/gecco/data/user_phantoms/Patient_Head_Female_01/fastmc_output/fastmc_216.00_2-scatter.mhd
# [2024-06-07 10:42:28,330] {patient_data.py:265} INFO -           Shape:(360, 360)
# [2024-06-07 10:42:28,330] {patient_data.py:263} INFO -         /home/berbecolab/Software/gecco-master/gecco/data/user_phantoms/Patient_Head_Female_01/fastmc_output/fastmc_252.00_2-scatter.mhd
# [2024-06-07 10:42:28,330] {patient_data.py:265} INFO -           Shape:(360, 360)
# [2024-06-07 10:42:28,330] {patient_data.py:263} INFO -         /home/berbecolab/Software/gecco-master/gecco/data/user_phantoms/Patient_Head_Female_01/fastmc_output/fastmc_288.00_2-scatter.mhd
# [2024-06-07 10:42:28,331] {patient_data.py:265} INFO -           Shape:(360, 360)
# [2024-06-07 10:42:28,331] {patient_data.py:263} INFO -         /home/berbecolab/Software/gecco-master/gecco/data/user_phantoms/Patient_Head_Female_01/fastmc_output/fastmc_324.00_2-scatter.mhd
# [2024-06-07 10:42:28,331] {patient_data.py:265} INFO -           Shape:(360, 360)
# [2024-06-07 10:42:28,331] {patient_data.py:263} INFO -         /home/berbecolab/Software/gecco-master/gecco/data/user_phantoms/Patient_Head_Female_01/fastmc_output/fastmc_36.00_2-scatter.mhd
# [2024-06-07 10:42:28,331] {patient_data.py:265} INFO -           Shape:(360, 360)
# [2024-06-07 10:42:28,331] {patient_data.py:263} INFO -         /home/berbecolab/Software/gecco-master/gecco/data/user_phantoms/Patient_Head_Female_01/fastmc_output/fastmc_72.00_2-scatter.mhd
# [2024-06-07 10:42:28,331] {patient_data.py:265} INFO -           Shape:(360, 360)

# %%
# Source spectrum
spectrum = fc.calculate_spectrum_sp(125,12)

# phantom.phantom = np.flip(phantom.phantom,axis=[2])
# Beam filters
spectrum.filter('Be', 1.5)
spectrum.filter('Al', 2.75)
spectrum.filter('Ti', 0.89)

# Detector filters
spectrum.filter('Al', 3.7)
spectrum.filter('C', 3.8*(2/1.7)) # Difference in density

# First layer filters
spectrum.filter('Cesium Iodide',0.6*0.71) # 71% fill factor
spectrum.filter('Si',1.1)

phantom.xx, phantom.yy = spectrum.get_points()
phantom.run_gecco(1e20,360,conv_on=False)
# Out:
# [2024-06-07 10:42:36,896] {patient_data.py:609} INFO - Making a list of angles
# [2024-06-07 10:42:36,896] {patient_data.py:637} INFO - Detector matching specifications: CsI-784-micrometer
# [2024-06-07 10:42:36,899] {ggems_simulate.py:204} INFO - Initializing filter /home/berbecolab/Software/gecco-master/gecco/data/bowties/full_fan_alt.dat
# [2024-06-07 10:42:37,101] {ggems_simulate.py:581} INFO - Running Simulations: 360 Projections
# [2024-06-07 10:42:37,102] {ggems_simulate.py:609} INFO -     Simulating 10 keV
# [2024-06-07 10:42:37,114] {ggems_simulate.py:688} INFO -         Attenuation at 10 keV for SchneiderMaterialsWe
{ggems_simulate.py:688} INFO -         Attenuation at 100 keV for SchneiderMaterialsWeight7 is 0.15146850654917182
# [2024-06-07 10:42:42,703] {ggems_simulate.py:688} INFO -         Attenuation at 100 keV for SchneiderMaterialsWeight8 is 0.1514060898855768
# [2024-06-07 10:42:42,709] {ggems_simulate.py:688} INFO -         Attenuation at 100 keV for SchneiderMaterialsWeight9 is 0.15007622935743054
# [2024-06-07 10:42:42,713] {ggems_simulate.py:688} INFO -         Attenuation at 100 keV for SchneiderMaterialsWeight10 is 0.1520393087469352
# [2024-06-07 10:42:42,715] {ggems_simulate.py:688} INFO -         Attenuation at 100 keV for SchneiderMaterialsWeight11 is 0.15232346291098847
# [2024-06-07 10:42:42,718] {ggems_simulate.py:688} INFO -         Attenuation at 100 keV for SchneiderMaterialsWeight12 is 0.15247703627633247
# [2024-06-07 10:42:42,720] {ggems_simulate.py:688} INFO -         Attenuation at 100 keV for SchneiderMaterialsWeight13 is 0.15268934471339574
# [2024-06-07 10:42:42,722] {ggems_simulate.py:688} INFO -         Attenuation at 100 keV for SchneiderMaterialsWeight14 is 0.15290292056760196
# [2024-06-07 10:42:42,724] {ggems_simulate.py:688} INFO -         Attenuation at 100 keV for SchneiderMaterialsWeight15 is 0.15308852375685347
# [2024-06-07 10:42:42,726] {ggems_simulate.py:688} INFO -         Attenuation at 100 keV for SchneiderMaterialsWeight16 is 0.15320956661385046
# [2024-06-07 10:42:42,728] {ggems_simulate.py:688} INFO -         Attenuation at 100 keV for SchneiderMaterialsWeight17 is 0.15330961712167118
# [2024-06-07 10:42:42,730] {ggems_simulate.py:688} INFO -         Attenuation at 100 keV for SchneiderMaterialsWeight18 is 0.15340046766628238
# [2024-06-07 10:42:42,733] {ggems_simulate.py:688} INFO -         Attenuation at 100 keV for SchneiderMaterialsWeight19 is 0.15362032395280917
# [2024-06-07 10:42:42,735] {ggems_simulate.py:688} INFO -         Attenuation at 100 keV for SchneiderMaterialsWeight20 is 0.1537066363423544
# [2024-06-07 10:42:42,737] {ggems_simulate.py:688} INFO -         Attenuation at 100 keV for SchneiderMaterialsWeight21 is 0.15381488563545123
# [2024-06-07 10:42:42,740] {ggems_simulate.py:688} INFO -         Attenuation at 100 keV for SchneiderMaterialsWeight22 is 0.15392100051609414
# [2024-06-07 10:42:42,742] {ggems_simulate.py:688} INFO -         Attenuation at 100 keV for SchneiderMaterialsWeight23 is 0.15402498444419202
# [2024-06-07 10:42:42,744] {ggems_simulate.py:688} INFO -         Attenuation at 100 keV for SchneiderMaterialsWeight24 is 0.15410025505490138
# [2024-06-07 10:42:42,745] {ggems_simulate.py:688} INFO -         Attenuation at 100 keV for SchneiderMaterialsWeight25 is 0.18529688526447843
# [2024-06-07 10:42:43,208] {ggems_simulate.py:714} INFO -       Phantom is_patient: True, using density correction
# [2024-06-07 10:42:43,258] {ggems_simulate.py:873} INFO - Weighting simulations
# [2024-06-07 10:42:44,805] {ggems_simulate.py:916} INFO - Simulation Finished
# [2024-06-07 10:42:44,805] {ggems_simulate.py:917} INFO -     Analytical projections are stored as: phantom.primary_projections
# [2024-06-07 10:42:44,805] {ggems_simulate.py:919} INFO -     Analytical flood field are stored as: phantom.flood_field

# %%
phantom.correct_intensity(ml=False,crop=40)
# phantom.sim_angles = np.linspace(0,2*np.pi,10)
phantom.interpolate_ggems_scatter()
phantom.calc_gecco_projections(scat_weight=0.48,noise_weight=100) # Creates the gecco projections scatter to primary reduction from asg is 0.48 assumed half is taken by scatter correction
# phantom.add_poisson_noise(0.5)
phantom.reconstruct_ggems(algo="FDK",filt='ram_lak')

# %%
plt.figure(figsize=[10,6])
plt.subplot(121)
plt.imshow(np.flipud(phantom.img[40,:,:]),cmap='gray',aspect='equal',vmin=np.percentile(phantom.img[40],40),vmax=np.percentile(phantom.img[40],98))
# plt.title('GECCO CBCT')
plt.axis('off')
plt.subplot(122)
plt.imshow(np.flipud(phantom.density[40,:,:]),cmap='gray',aspect='equal',vmin=np.percentile(phantom.density[40],40),vmax=np.percentile(phantom.density[40],98))
# plt.title('Clinical CT')
plt.axis('off')
plt.tight_layout()

# %%
from gecco.utils import gecco_python_script_head, write_run_all_script


output_dir = 'gecco_data'

output_dir_abs = os.path.join(os.getcwd(),output_dir)

for key,nrrd in nrrd_files.items():
    print(key + ' : ' + nrrd[0])

    test_file_name = nrrd[0].split('/')[-1].split('.')[0] + '_test.py'
    test_sim_dir = './test_gecco_scripts'
    sim_num = nrrd[3]

    gecco_python_script_head(nrrd[0],os.path.join(test_sim_dir,test_file_name), 
                               output_dir_abs, sim_num, test=True)

# Combine the current working directory with the test_sim_dir
test_sim_dir_abs = os.path.join(os.getcwd(),test_sim_dir)
write_run_all_script(test_sim_dir_abs)

# Make the script executable
# !chmod +x ./test_gecco_scripts/run_all.sh
# Out:
# 0 : /home/berbecolab/2-Datadir/Clinical_data/Head/Patient_Head_Female_01.nrrd
# 1 : /home/berbecolab/2-Datadir/Clinical_data/Head/Patient_Head_Female_02a.nrrd
# 2 : /home/berbecolab/2-Datadir/Clinical_data/Head/Patient_Head_Female_03.nrrd
# 3 : /home/berbecolab/2-Datadir/Clinical_data/Head/Patient_Head_Female_04.nrrd
# 4 : /home/berbecolab/2-Datadir/Clinical_data/Head/Patient_Head_Female_05.nrrd
# 5 : /home/berbecolab/2-Datadir/Clinical_data/Head/Patient_Head_Male_01.nrrd
# 6 : /home/berbecolab/2-Datadir/Clinical_data/Head/Patient_Head_Male_02.nrrd
# 7 : /home/berbecolab/2-Datadir/Clinical_data/Head/Patient_Head_Male_03.nrrd
# 8 : /home/berbecolab/2-Datadir/Clinical_data/Head/Patient_Head_Male_04.nrrd
# 9 : /home/berbecolab/2-Datadir/Clinical_data/Head/Patient_Head_Male_05.nrrd
# 10 : /home/berbecolab/2-Datadir/Clinical_data/Head/Patient_Head_Male_06.nrrd
# 11 : /home/berbecolab/2-Datadir/Clinical_data/Head/Patient_Head_Male_07.nrrd
# 12 : /home/berbecolab/2-Datadir/Clinical_data/Head/Patient_Head_Male_08.nrrd
# 13 : /home/berbecolab/2-Datadir/Clinical_data/Head/Patient_Head_Female_02b.nrrd
# [2024-06-07 10:54:57,130] {utils.py:1021} INFO - Script written to run all Python files in the directory

# %%
from gecco.utils import gecco_python_script_pelvis, write_run_all_script


output_dir = 'gecco_data'

output_dir_abs = os.path.join(os.getcwd(),output_dir)

for key,nrrd in nrrd_files.items():
    print(key + ' : ' + nrrd[0])

    test_file_name = nrrd[0].split('/')[-1].split('.')[0] + '.py'
    test_sim_dir = './gecco_scripts'
    sim_num = nrrd[3]

    gecco_python_script_pelvis(nrrd[0],os.path.join(test_sim_dir,test_file_name), 
                               output_dir_abs, sim_num, test=False)

# Combine the current working directory with the test_sim_dir
test_sim_dir_abs = os.path.join(os.getcwd(),test_sim_dir)
write_run_all_script(test_sim_dir_abs)

# Make the script executable
# !chmod +x ./gecco_scripts/run_all.sh
# Out:
# 0 : /home/berbecolab/2-Datadir/Clinical_data/Pelvis/Pelvis_Female_Patient_1.nrrd
# 1 : /home/berbecolab/2-Datadir/Clinical_data/Pelvis/Pelvis_Female_Patient_2.nrrd
# 2 : /home/berbecolab/2-Datadir/Clinical_data/Pelvis/Pelvis_Female_Patient_3.nrrd
# 3 : /home/berbecolab/2-Datadir/Clinical_data/Pelvis/Pelvis_Prostate_Patient_1.nrrd
# 4 : /home/berbecolab/2-Datadir/Clinical_data/Pelvis/Pelvis_Prostate_Patient_2.nrrd
# 5 : /home/berbecolab/2-Datadir/Clinical_data/Pelvis/Pelvis_Prostate_Patient_3.nrrd
# 6 : /home/berbecolab/2-Datadir/Clinical_data/Pelvis/Pelvis_Prostate_Patient_4.nrrd
# 7 : /home/berbecolab/2-Datadir/Clinical_data/Pelvis/Pelvis_Prostate_Patient_5.nrrd
# [2024-06-05 15:19:52,467] {utils.py:1020} INFO - Script written to run all Python files in the directory

# %%
from gecco.utils import gecco_python_script_pelvis, write_run_all_script


output_dir = 'gecco_data_matlab'


output_dir_abs = os.path.join(os.getcwd(),output_dir)

if not os.path.exists(output_dir_abs):
    os.mkdir(output_dir_abs)

for key,nrrd in nrrd_files.items():
    print(key + ' : ' + nrrd[0])

    test_file_name = nrrd[0].split('/')[-1].split('.')[0] + '.py'
    test_sim_dir = './gecco_scripts_matlab'
    sim_num = nrrd[3]

    gecco_python_script_pelvis(nrrd[0],os.path.join(test_sim_dir,test_file_name), 
                               output_dir_abs, sim_num, test=False,matlab=True)

# Combine the current working directory with the test_sim_dir
test_sim_dir_abs = os.path.join(os.getcwd(),test_sim_dir)
write_run_all_script(test_sim_dir_abs)

# Make the script executable
# !chmod +x ./gecco_scripts_matlab/run_all.sh
# Out:
# 0 : /home/berbecolab/2-Datadir/Clinical_data/Head/Patient_Head_Female_01.nrrd
# 1 : /home/berbecolab/2-Datadir/Clinical_data/Head/Patient_Head_Female_02a.nrrd
# 2 : /home/berbecolab/2-Datadir/Clinical_data/Head/Patient_Head_Female_03.nrrd
# 3 : /home/berbecolab/2-Datadir/Clinical_data/Head/Patient_Head_Female_04.nrrd
# 4 : /home/berbecolab/2-Datadir/Clinical_data/Head/Patient_Head_Female_05.nrrd
# 5 : /home/berbecolab/2-Datadir/Clinical_data/Head/Patient_Head_Male_01.nrrd
# 6 : /home/berbecolab/2-Datadir/Clinical_data/Head/Patient_Head_Male_02.nrrd
# 7 : /home/berbecolab/2-Datadir/Clinical_data/Head/Patient_Head_Male_03.nrrd
# 8 : /home/berbecolab/2-Datadir/Clinical_data/Head/Patient_Head_Male_04.nrrd
# 9 : /home/berbecolab/2-Datadir/Clinical_data/Head/Patient_Head_Male_05.nrrd
# 10 : /home/berbecolab/2-Datadir/Clinical_data/Head/Patient_Head_Male_06.nrrd
# 11 : /home/berbecolab/2-Datadir/Clinical_data/Head/Patient_Head_Male_07.nrrd
# 12 : /home/berbecolab/2-Datadir/Clinical_data/Head/Patient_Head_Male_08.nrrd
# 13 : /home/berbecolab/2-Datadir/Clinical_data/Head/Patient_Head_Female_02b.nrrd
# [2024-06-07 11:07:03,595] {utils.py:1021} INFO - Script written to run all Python files in the directory
