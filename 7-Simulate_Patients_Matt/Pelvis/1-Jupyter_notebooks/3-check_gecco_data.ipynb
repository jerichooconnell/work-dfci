# %%
# %matplotlib inline

# %%
import os
import numpy as np

def load_npy_files_to_dict(directory):
    data_dict = {}

    for root, dirs, files in os.walk(directory):
        for file in files:
            if file.endswith('.npy'):
                array = np.load(os.path.join(root, file))
                data_dict[os.path.splitext(file)[0]] = array  # Use file name as key

    return data_dict

data_dict = load_npy_files_to_dict('./gecco_data')

# %%
import matplotlib.pyplot as plt
import numpy as np

def process_dict(data_dict):
    for key, array in data_dict.items():
        print(f"Key: {key}")
        print(f"Mean: {np.mean(array)}")
        print(f"Max: {np.max(array)}")
        print(f"Min: {np.min(array)}")

        plt.figure()
        if array.ndim == 1:
            plt.plot(array)
        elif array.ndim == 2:
            plt.imshow(array)
        elif array.ndim == 3:
            # For 3D arrays, plot a slice in the middle
            plt.imshow(array[array.shape[0] // 2])
        plt.title(key)
        plt.show()

process_dict(data_dict)
# Out:
# Key: Pelvis_Female_Patient_3_primary_first_layer
# Mean: 6669.694050037183
# Max: 41915.7197166605
# Min: 537.0121905897777
# Key: Pelvis_Female_Patient_3_primary_second_layer
# Mean: 4100.389164221043
# Max: 26367.77216992938
# Min: 321.63398971711814
# Key: Pelvis_Female_Patient_3_flood_first_layer
# Mean: 29780.04412885327
# Max: 56166.896569729826
# Min: 11558.393845692624
# Key: Pelvis_Female_Patient_3_scatter_second_layer
# Mean: 272.46743209876536
# Max: 465.7746184430215
# Min: 65.03889494720798
# Key: Pelvis_Female_Patient_3_flood_second_layer
# Mean: 18675.25129382354
# Max: 35576.766811086396
# Min: 7095.0186682191215
# Key: Pelvis_Female_Patient_3_scatter_first_layer
# Mean: 483.8580131172837
# Max: 800.2329357883348
# Min: 118.92400781618328
# Key: Pelvis_Female_Patient_2_scatter_first_layer
# Mean: 433.61892206790117
# Max: 664.5943762801787
# Min: 165.76602720275378
# Key: Pelvis_Female_Patient_2_primary_first_layer
# Mean: 5500.069625513488
# Max: 21840.177185494875
# Min: 32.065086454935724
# Key: Pelvis_Female_Patient_2_scatter_second_layer
# Mean: 251.0099575617283
# Max: 390.40419035411605
# Min: 90.63906646134394
# Key: Pelvis_Female_Patient_2_primary_second_layer
# Mean: 3371.5865430435942
# Max: 13539.995298350394
# Min: 19.037313533183482
# Key: Pelvis_Female_Patient_2_flood_first_layer
# Mean: 29782.171428642596
# Max: 56170.908780951635
# Min: 11559.219504939012
# Key: Pelvis_Female_Patient_2_flood_second_layer
# Mean: 18665.328813724187
# Max: 35557.86426701197
# Min: 7091.248963574599
# Key: Pelvis_Prostate_Patient_1_primary_first_layer
# Mean: 1328.3311264502056
# Max: 12673.623482880323
# Min: 72.01886286736513
# Key: Pelvis_Prostate_Patient_1_scatter_second_layer
# Mean: 169.32381172839507
# Max: 312.6977175597901
# Min: 48.658627144326736
# Key: Pelvis_Prostate_Patient_1_flood_first_layer
# Mean: 29784.34678589452
# Max: 56175.01163134507
# Min: 11560.063816511016
# Key: Pelvis_Prostate_Patient_1_scatter_first_layer
# Mean: 295.22302700617274
# Max: 548.0397101147903
# Min: 94.57224006356907
# Key: Pelvis_Prostate_Patient_1_flood_second_layer
# Mean: 18678.268889439212
# Max: 35582.515397483425
# Min: 7096.16509976585
# Key: Pelvis_Prostate_Patient_1_primary_second_layer
# Mean: 811.353450906302
# Max: 7779.742454920395
# Min: 43.10772164553479
# Key: Pelvis_Prostate_Patient_2_primary_first_layer
# Mean: 3203.7237355909124
# Max: 21858.158640839934
# Min: 13.78846167307556
# Key: Pelvis_Prostate_Patient_2_primary_second_layer
# Mean: 1965.179895392687
# Max: 13547.055121798672
# Min: 8.192893989277943
# Key: Pelvis_Prostate_Patient_2_scatter_first_layer
# Mean: 405.5622445987657
# Max: 594.520420576801
# Min: 165.8392667698961
# Key: Pelvis_Prostate_Patient_2_flood_second_layer
# Mean: 18682.606346091055
# Max: 35590.77834834967
# Min: 7097.812967065368
# Key: Pelvis_Prostate_Patient_2_flood_first_layer
# Mean: 29771.457458433004
# Max: 56150.70160953141
# Min: 11555.061140136135
# Key: Pelvis_Prostate_Patient_2_scatter_second_layer
# Mean: 232.7726975308643
# Max: 355.77013767228544
# Min: 88.91617918550915
# Key: Pelvis_Prostate_Patient_3_scatter_first_layer
# Mean: 364.245466820988
# Max: 551.8812461917603
# Min: 169.24703001740875
# Key: Pelvis_Prostate_Patient_3_flood_second_layer
# Mean: 18683.770819998976
# Max: 35592.99669690242
# Min: 7098.25536882936
# Key: Pelvis_Prostate_Patient_3_flood_first_layer
# Mean: 29775.717192918608
# Max: 56158.73571670843
# Min: 11556.714451617128
# Key: Pelvis_Prostate_Patient_3_primary_first_layer
# Mean: 4142.656136647849
# Max: 27650.273367954334
# Min: 29.54425130272622
# Key: Pelvis_Prostate_Patient_3_scatter_second_layer
# Mean: 209.71619830246908
# Max: 315.4434485953843
# Min: 91.32391528322921
# Key: Pelvis_Prostate_Patient_3_primary_second_layer
# Mean: 2541.681862999477
# Max: 17206.20250703938
# Min: 17.545837882087465
# Key: Pelvis_Prostate_Patient_5_flood_second_layer
# Mean: 18675.601597194192
# Max: 35577.43414675619
# Min: 7095.151753922505
# Key: Pelvis_Prostate_Patient_5_scatter_second_layer
# Mean: 165.00733256172836
# Max: 254.5425805582696
# Min: 61.82834417691484
# Key: Pelvis_Prostate_Patient_5_flood_first_layer
# Mean: 29785.096785138798
# Max: 56176.42617357337
# Min: 11560.354910325781
# Key: Pelvis_Prostate_Patient_5_primary_second_layer
# Mean: 6957.861871249243
# Max: 35577.43086133167
# Min: 324.1052832274046
# Key: Pelvis_Prostate_Patient_5_scatter_first_layer
# Mean: 283.2851874999999
# Max: 437.28330535824904
# Min: 96.4045718881626
# Key: Pelvis_Prostate_Patient_5_primary_first_layer
# Mean: 11180.15904296515
# Max: 56176.40726072003
# Min: 541.6613723154784
# Key: Pelvis_Female_Patient_1_scatter_first_layer
# Mean: 337.33235108024695
# Max: 521.1987818223141
# Min: 145.2961686179119
# Key: Pelvis_Female_Patient_1_scatter_second_layer
# Mean: 195.24386574074066
# Max: 304.8710700258275
# Min: 85.66462128447176
# Key: Pelvis_Female_Patient_1_flood_second_layer
# Mean: 18682.766888617447
# Max: 35591.084185413645
# Min: 7097.873959670173
# Key: Pelvis_Female_Patient_1_primary_first_layer
# Mean: 5980.8011454546495
# Max: 28972.397296137435
# Min: 50.663103923308945
# Key: Pelvis_Female_Patient_1_primary_second_layer
# Mean: 3672.967375574781
# Max: 18074.394445745686
# Min: 30.086471313977867
# Key: Pelvis_Female_Patient_1_flood_first_layer
# Mean: 29778.91084172035
# Max: 56164.75912423434
# Min: 11557.953988083082
# Key: Pelvis_Prostate_Patient_4_primary_first_layer
# Mean: 4287.994226469583
# Max: 17718.80179170204
# Min: 28.70312164536809
# Key: Pelvis_Prostate_Patient_4_scatter_first_layer
# Mean: 374.60953858024675
# Max: 537.111475559902
# Min: 160.05135800441332
# Key: Pelvis_Prostate_Patient_4_scatter_second_layer
# Mean: 215.87166203703686
# Max: 314.7734183807201
# Min: 85.64626734223415
# Key: Pelvis_Prostate_Patient_4_flood_second_layer
# Mean: 18679.840956244494
# Max: 35585.51021952159
# Min: 7096.762352416199
# Key: Pelvis_Prostate_Patient_4_flood_first_layer
# Mean: 29784.79818371575
# Max: 56175.86299390945
# Min: 11560.239015505897
# Key: Pelvis_Prostate_Patient_4_primary_second_layer
# Mean: 2629.6791931677917
# Max: 10938.26162937045
# Min: 17.025722137672602
