# %%
# %matplotlib inline
# %load_ext autoreload
# %autoreload 2

# %%
import detector_class as dc
import spekpy as sp
import matplotlib.pyplot as plt
# Define the layers for the detector
materials = ['Al','Ti','Water','Cs','Sn','Si','Cs','Si']
densities = [None,None,1,None,None,None,None,None]
thicknesses = [1,1,0.6,1,0.1,0.8,0.1,0.1]
colors = ['gray','darkgray','blue','red','whitesmoke','white','red','white']

spectra = sp.Spek(kvp=140,th=14)

# Create the detector
detector = dc.Detector()
detector.add_layers(materials,thicknesses,densities=densities)
plt.figure(figsize=[5,10])
ax = plt.gca()
detector.plot_detector(ax,colors)
plt.show()

# %%
plt.figure()
ax = plt.gca()
detector.plot_attenuation(ax)
plt.show()
# Out:
# Al
# Ti
# Water
# Cs
# Sn
# Si
# Cs
# Si

# %%
s = sp.Spek(kvp=140,th=14)
s.filter('Cs',1)

# %%
detector.filter_spectrum_through_detector(s)
# Out:
# Al 1
# Ti 1
# Water 0.6
# Unexpected exception formatting exception. Falling back to standard exception
# Traceback (most recent call last):
#   File "/home/jericho/anaconda3/envs/opengate_env/lib/python3.9/site-packages/IPython/core/interactiveshell.py", line 3526, in run_code
#     exec(code_obj, self.user_global_ns, self.user_ns)
#   File "/tmp/ipykernel_189577/1068600243.py", line 1, in <module>
#     detector.filter_spectrum_through_detector(s)
#   File "/home/jericho/1-work/detector_class.py", line 225, in filter_spectrum_through_detector
#     self.spectra.append(self.filtered_spectrum(spectrum,layer.layer))
#   File "/home/jericho/1-work/detector_class.py", line 119, in __init__
#     self.filter_spectrum(spectrum, layer['material'],layer['thickness'],layer['density'])
#   File "/home/jericho/1-work/detector_class.py", line 154, in filter_spectrum
#     spectrum.filter(material,thickness,density)
# TypeError: filter() takes 3 positional arguments but 4 were given
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/home/jericho/anaconda3/envs/opengate_env/lib/python3.9/site-packages/IPython/core/interactiveshell.py", line 2120, in showtraceback
#     stb = self.InteractiveTB.structured_traceback(
#   File "/home/jericho/anaconda3/envs/opengate_env/lib/python3.9/site-packages/IPython/core/ultratb.py", line 1435, in structured_traceback
#     return FormattedTB.structured_traceback(
#   File "/home/jericho/anaconda3/envs/opengate_env/lib/python3.9/site-packages/IPython/core/ultratb.py", line 1326, in structured_traceback
#     return VerboseTB.structured_traceback(
#   File "/home/jericho/anaconda3/envs/opengate_env/lib/python3.9/site-packages/IPython/core/ultratb.py", line 1173, in structured_traceback
#     formatted_exception = self.format_exception_as_a_whole(etype, evalue, etb, number_of_lines_of_context,
#   File "/home/jericho/anaconda3/envs/opengate_env/lib/python3.9/site-packages/IPython/core/ultratb.py", line 1088, in format_exception_as_a_whole
#     frames.append(self.format_record(record))
#   File "/home/jericho/anaconda3/envs/opengate_env/lib/python3.9/site-packages/IPython/core/ultratb.py", line 970, in format_record
#     frame_info.lines, Colors, self.has_colors, lvals
#   File "/home/jericho/anaconda3/envs/opengate_env/lib/python3.9/site-packages/IPython/core/ultratb.py", line 792, in lines
#     return self._sd.lines
#   File "/home/jericho/anaconda3/envs/opengate_env/lib/python3.9/site-packages/stack_data/utils.py", line 145, in cached_property_wrapper
#     value = obj.__dict__[self.func.__name__] = self.func(obj)
#   File "/home/jericho/anaconda3/envs/opengate_env/lib/python3.9/site-packages/stack_data/core.py", line 698, in lines
#     pieces = self.included_pieces
#   File "/home/jericho/anaconda3/envs/opengate_env/lib/python3.9/site-packages/stack_data/utils.py", line 145, in cached_property_wrapper
#     value = obj.__dict__[self.func.__name__] = self.func(obj)
#   File "/home/jericho/anaconda3/envs/opengate_env/lib/python3.9/site-packages/stack_data/core.py", line 649, in included_pieces
#     pos = scope_pieces.index(self.executing_piece)
#   File "/home/jericho/anaconda3/envs/opengate_env/lib/python3.9/site-packages/stack_data/utils.py", line 145, in cached_property_wrapper
#     value = obj.__dict__[self.func.__name__] = self.func(obj)
#   File "/home/jericho/anaconda3/envs/opengate_env/lib/python3.9/site-packages/stack_data/core.py", line 628, in executing_piece
#     return only(
#   File "/home/jericho/anaconda3/envs/opengate_env/lib/python3.9/site-packages/executing/executing.py", line 164, in only
#     raise NotOneValueFound('Expected one value, found 0')
# executing.executing.NotOneValueFound: Expected one value, found 0

# %%
mat = xrd.add_material('CsI','CsI',density=3.7)

# %%
mats = xrd.chemparse('CsI')
masses = []
perc_masses = []
for key in mats:
    print(xrd.atomic_mass(key))
    masses.append(xrd.atomic_mass(key))

for ii, key in enumerate(mats):
    print(masses[ii]/np.sum(masses))
# Out:
# 132.905
# 126.905
# 0.5115468996574419
# 0.488453100342558

# %%
xrd.utils.
# Out:
# {'Cs': 1, 'I': 1}
